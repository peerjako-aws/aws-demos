# %% [markdown]
# # Train faster, more flexible models with Amazon SageMaker Linear Learner

# %% [markdown]
# Today Amazon SageMaker is launching several additional features to the built-in linear learner algorithm.  Amazon SageMaker algorithms are designed to scale effortlessly to massive datasets and take advantage of the latest hardware optimizations for unparalleled speed.  The Amazon SageMaker linear learner algorithm encompasses both linear regression and binary classification algorithms.  These algorithms are used extensively in banking, fraud/risk management, insurance, and healthcare.  The new features of linear learner are designed to speed up training and help you customize models for different use cases.  Examples include classification with unbalanced classes, where one of your outcomes happens far less frequently than another.  Or specialized loss functions for regression, where it’s more important to penalize certain model errors more than others.
#
# In this blog post we'll cover three things:
# 1. Early stopping and saving the best model
# 1. New ways to customize linear learner models, including:
#    * Hinge loss (support vector machines)
#    * Quantile loss
#    * Huber loss
#    * Epsilon-insensitive loss
#    * Class weights options
# 1. Then we'll walk you through a hands-on example of using class weights to boost performance in binary classification

# %% [markdown]
# ## Early Stopping
#
# Linear learner trains models using Stochastic Gradient Descent (SGD) or variants of SGD like Adam.  Training requires multiple passes over the data, called *epochs*, in which the data are loaded into memory in chunks called *batches*, sometimes called *minibatches*.  How do we know how many epochs to run?  Ideally, we'd like to continue training until convergence - that is, until we no longer see any additional benefits.  Running additional epochs after the model has converged is a waste of time and money, but guessing the right number of epochs is difficult to do before submitting a training job.  If we train for too few epochs, our model will be less accurate than it should be, but if we train for too many epochs, we'll waste resources and potentially harm model accuracy by overfitting.  To remove the guesswork and optimize model training, linear learner has added two new features: automatic early stopping and saving the best model.
#
# Early stopping works in two basic regimes: with or without a validation set.  Often we split our data into training, validation, and testing data sets.  Training is for optimizing the loss, validation is for tuning hyperparameters, and testing is for producing an honest estimate of how the model will perform on unseen data in the future.  If you provide linear learner with a validation data set, training will stop early when validation loss stops improving.  If no validation set is available, training will stop early when training loss stops improving.
#
# #### Early Stopping with a validation data set
# One big benefit of having a validation data set is that we can tell if and when we start overfitting to the training data.  Overfitting is when the model gives predictions that are too closely tailored to the training data, so that generalization performance (performance on future unseen data) will be poor.  The following plot on the right shows a typical progression during training with a validation data set.  Until epoch 5, the model has been learning from the training set and doing better and better on the validation set.  But in epochs 7-10, we see that the model has begun to overfit on the training set, which shows up as worse performance on the validation set.  Regardless of whether the model continues to improve (overfit) on the training data, we want to stop training after the model starts to overfit.  And we want to restore the best model from just before the overfitting started.  These two features are now turned on by default in linear learner.
#
# The default parameter values for early stopping are shown in the following code.  To tweak the behavior of early stopping, try changing the values.  To turn off early stopping entirely, choose a patience value larger than the number of epochs you want to run.

# %% [markdown]
#     early_stopping_patience=3,
#     early_stopping_tolerance=0.001,

# %% [markdown]
# The parameter early_stoping_patience defines how many epochs to wait before ending training if no improvement is made.  It's useful to have a little patience when deciding to stop early, since the training curve can be bumpy.  Performance may get worse for one or two epochs before continuing to improve.  By default, linear learner will stop early if performance has degraded for three epochs in a row.
#
# The parameter early_stopping_tolerance defines the size of an improvement that's considered significant.  If the ratio of the improvement in loss divided by the previous best loss is smaller than this value, early stopping will consider the improvement to be zero.

# %% [markdown]
# #### Early stopping without a validation data set
#
# When training with a training set only, we have no way to detect overfitting.  But we still want to stop training once the model has converged and improvement has levelled off.  In the left panel of the following figure, that happens around epoch 25.

# %% [markdown]
# <img src="images/early_stop.png">

# %% [markdown]
# #### Early stopping and calibration
# You may already be familiar with the linear learner automated threshold tuning for binary classification models.  Threshold tuning and early stopping work together seamlessly by default in linear learner.
#
# When a binary classification model outputs a probability (e.g., logistic regression) or a raw score (SVM), we convert that to a binary prediction by applying a threshold, for example:

# %% [markdown]
#     predicted_label = 1 if raw_prediction > 0.5 else 0

# %% [markdown]
# We might want to tune the threshold (0.5 in the example) based on the metric we care about most, such as accuracy or recall.  Linear learner does this tuning automatically using the 'binary_classifier_model_selection_criteria' parameter.  When threshold tuning and early stopping are both turned on (the default), then training stops early based on the metric you request.  For example, if you provide a validation data set and request a logistic regression model with threshold tuning based on accuracy, then training will stop when the model with auto-thresholding reaches optimal performance on the validation data.  If there is no validation set and auto-thresholding is turned off, then training will stop when the best value of the loss function on the training data is reached.

# %% [markdown]
# ## New loss functions
#
# The loss function is our definition of the cost of making an error in prediction.  When we train a model, we push the model weights in the direction that minimizes loss, given the known labels in the training set.  The most common and well-known loss function is squared loss, which is minimized when we train a standard linear regression model.  Another common loss function is the one used in logistic regression, variously known as logistic loss, cross-entropy loss, or binomial likelihood.  Ideally, the loss function we train on should be a close match to the business problem we're trying to solve.  Having the flexibility to choose different loss functions at training time allows us to customize models to different use cases.  In this section, we'll discuss when to use which loss function, and introduce several new loss functions that have been added to linear learner.

# %% [markdown]
# <img src="images/loss_functions.png">

# %% [markdown]
# ### Squared loss

# %% [markdown]
#     predictor_type='regressor',
#     loss='squared_loss',

# %% [markdown]
# $$\text{argmin}_{w_0, \mathbf{w}} \sum_{i=1}^{N} (w_0 + \mathbf{x_i}^\intercal \mathbf{w} - y_i)^2$$
#
# We'll use the following notation in all of the loss functions we discuss:
#
# $w_0$ is the bias that the model learns
#
# $\mathbf{w}$ is the vector of feature weights that the model learns
#
# $y_i$ and $\mathbf{x_i}$ are the label and feature vector, respectively, from example $i$ of the training data
#
# $N$ is the total number of training examples
#
# Squared loss is a first choice for most regression problems.  It has the nice property of producing an estimate of the mean of the label given the features.  As seen in the plot above, squared loss implies that we pay a very high cost for very wrong predictions.  This can cause problems if our training data include some extreme outliers.  A model trained on squared loss will be very sensitive to outliers.  Squared loss is sometimes known as mean squared error (MSE), ordinary least squares (OLS), or $\text{L}_2$ loss.   Read more about [squared loss](https://en.wikipedia.org/wiki/Least_squares) on wikipedia.

# %% [markdown]
# ### Absolute loss

# %% [markdown]
#     predictor_type='regressor',
#     loss='absolute_loss',

# %% [markdown]
# $$\text{argmin}_{w_0, \mathbf{w}} \sum_{i=1}^{N} |w_0 + \mathbf{x_i}^\intercal \mathbf{w} - y_i|$$
#
# Absolute loss is less common than squared loss, but can be very useful.  The main difference between the two is that training a model on absolute loss will produces estimates of the median of the label given the features.  Squared loss estimates the mean, and absolute loss estimates the median.  Whether you want to estimate the mean or median will depend on your use case.  Let's look at a few examples:
# * If an error of -2 costs you \$2 and an error of +50 costs you \$50, then absolute loss models your costs better than squared loss.
# * If an error of -2 costs you \$2, while an error of +50 is simply unacceptably large, then it's important that your errors are generally small, and so squared loss is probably the right fit.
# * If it's important that your predictions are too high as often as they're too low, then you want to estimate the median with absolute loss.
# * If outliers in your training data are having too much influence on the model, try switching from squared to absolute loss.  Large errors get a large amount of attention from absolute loss, but with squared loss, large errors get squared and become huge errors attracting a huge amount of attention.  If the error is due to an outlier, it might not deserve a huge amount of attention.
#
# Absolute loss is sometimes also known as $\text{L}_1$ loss or least absolute error.  Read more about [absolute loss](https://en.wikipedia.org/wiki/Least_absolute_deviations) on wikipedia.

# %% [markdown]
# ### Quantile loss

# %% [markdown]
#     predictor_type='regressor',
#     loss='quantile_loss',
#     quantile=0.9,

# %% [markdown]
# $$ \text{argmin}_{w_0, \mathbf{w}} \sum_{i=1}^N q(y_i - w_o - \mathbf{x_i}^\intercal \mathbf{w})^\text{+} + (1-q)(w_0 + \mathbf{x_i}^\intercal \mathbf{w} - y_i)^\text{+} $$
#
# $$ \text{where the parameter } q \text{ is the quantile you want to predict}$$
#
# Quantile loss lets us predict an upper or lower bound for the label, given the features. To make predictions that are larger than the true label 90% of the time, train quantile loss with the 0.9 quantile. An example would be predicting electricity demand where we want to build near peak demand since building to the average would result in brown-outs and upset customers.  Read more about [quantile loss](https://en.wikipedia.org/wiki/Quantile_regression) on wikipedia.

# %% [markdown]
# ### Huber loss

# %% [markdown]
#     predictor_type='regressor',
#     loss='huber_loss',
#     huber_delta=0.5,

# %% [markdown]
# $$ \text{Let the error be } e_i = w_0 + \mathbf{x_i}^\intercal \mathbf{w} - y_i \text{.  Then Huber loss solves:}$$
#
# $$ \text{argmin}_{w_0, \mathbf{w}} \sum_{i=1}^N I(|e_i| < \delta) \frac{e_i^2}{2} + I(|e_i| >= \delta) |e_i|\delta - \frac{\delta^2}{2} $$
#
# $$ \text{where } I(a) = 1 \text{ if } a \text{ is true, else } 0 $$
#
# Huber loss is an interesting hybrid of $\text{L}_1$ and $\text{L}_2$ losses.  Huber loss counts small errors on a squared scale and large errors on an absolute scale.  In the plot above, we see that Huber loss looks like squared loss when the error is near 0 and absolute loss beyond that.  Huber loss is useful when we want to train with squared loss, but want to avoid squared loss's sensitivity to outliers.  Huber loss gives less importance to outliers by not squaring the larger errors.  Read more about [Huber loss](https://en.wikipedia.org/wiki/Huber_loss) on wikipedia.

# %% [markdown]
# ### Epsilon-insensitive loss

# %% [markdown]
#     predictor_type='regressor',
#     loss='eps_insensitive_squared_loss',
#     loss_insensitivity=0.25,

# %% [markdown]
# For epsilon-insensitive squared loss, we minimize
# $$ \text{argmin}_{w_0, \mathbf{w}} \sum_{i=1}^N max(0, (w_0 + \mathbf{x_i}^\intercal \mathbf{w} - y_i)^2 - \epsilon^2) $$
#
# And for epsilon-insensitive absolute loss, we minimize
#
# $$ \text{argmin}_{w_0, \mathbf{w}} \sum_{i=1}^N max(0, |w_0 + \mathbf{x_i}^\intercal \mathbf{w} - y_i| - \epsilon) $$
#
# Epsilon-insensitive loss is useful when errors don't matter to you as long as they're below some threshold.  Set the threshold that makes sense for your use case as epsilon.  Epsilon-insensitive loss will allow the model to pay no cost for making errors smaller than epsilon.

# %% [markdown]
# ### Logistic regression

# %% [markdown]
#     predictor_type='binary_classifier',
#     loss='logistic',
#     binary_classifier_model_selection_criteria='recall_at_target_precision',
#     target_precision=0.9,

# %% [markdown]
# Each of the losses we've discussed is for regression problems, where the labels are floating point numbers.  The last two losses we'll cover, logistic regression and support vector machines, are for binary classification problems where the labels are one of two classes.  Linear learner expects the class labels to be 0 or 1.  This may require some preprocessing, for example if your labels are coded as -1 and +1, or as blue and yellow.  Logistic regression produces a predicted probability for each data point:
#
# $$ p_i = \sigma(w_0 + \mathbf{x_i}^\intercal \mathbf{w}) $$
#
# The loss function minimized in training a logistic regression model is the log likelihood of a binomial distribution.  It assigns the highest cost to predictions that are confident and wrong, for example a prediction of 0.99 when the true label was 0, or a prediction of 0.002 when the true label was positive.  The loss function is:
#
# $$ \text{argmin}_{w_0, \mathbf{w}} \sum_{i=1}^N y_i  \text{log}(p) - (1 - y_i) \text{log}(1 - p) $$
#
# $$ \text{where } \sigma(x) = \frac{\text{exp}(x)}{1 + \text{exp}(x)}  $$
#
# Read more about [logistic regression](https://en.wikipedia.org/wiki/Logistic_regression) on wikipedia.

# %% [markdown]
# ### Hinge loss (support vector machine)

# %% [markdown]
#     predictor_type='binary_classifier',
#     loss='hinge_loss',
#     margin=1.0,
#     binary_classifier_model_selection_criteria='recall_at_target_precision',
#     target_precision=0.9,

# %% [markdown]
# Another popular option for binary classification problems is the hinge loss, also known as a Support Vector Machine (SVM) or Support Vector Classifier (SVC) with a linear kernel.  It places a high cost on any points that are misclassified or nearly misclassified.  To tune the meaning of "nearly", adjust the margin parameter:

# %% [markdown]
# It's difficult to say in advance whether logistic regression or SVM will be the right model for a binary classification problem, though logistic regression is generally a more popular choice then SVM.  If it's important to provide probabilities of the predicted class labels, then logistic regression will be the right choice.  If all that matters is better accuracy, precision, or recall, then either model may be appropriate.  One advantage of logistic regression is that it produces the probability of an example having a positive label.  That can be useful, for example in an ad serving system where the predicted click probability is used as an input to a bidding mechanism.  Hinge loss does not produce class probabilities.
#
# Whichever model you choose, you're likely to benefit from linear learner's options for tuning the threshold that separates positive from negative predictions
#
# $$\text{argmin}_{w_0, \mathbf{w}} \sum_{i=1}^{N} y_i(\frac{m+1}{2} - w_0 - \mathbf{x_i}^\text{T}\mathbf{w})^\text{+} + (1-y_i)\frac{m-1}{2} + w_o + \mathbf{x_i}^\text{T}\mathbf{w})^\text{+}$$
#
# $$\text{where  } a^\text{+} = \text{max}(0, a)$$
#
#
# Note that the hinge loss we use is a reparameterization of the usual hinge loss: typically hinge loss expects the binary label to be in {-1, 1}, whereas ours expects the binary labels to be in {0, 1}.  This reparameterization allows LinearLearner to accept the same data format for binary classification regardless of the training loss.  Read more about [hinge loss](https://en.wikipedia.org/wiki/Hinge_loss) on wikipedia.

# %% [markdown]
# ## Class weights
# In some binary classification problems, we may find that our training data is highly unbalanced.  For example, in credit card fraud detection, we're likely to have many more examples of non-fraudulent transactions than fraudulent.  In these cases, balancing the class weights may improve model performance.
#
# Suppose we have 98% negative and 2% positive examples.  To balance the total weight of each class, we can set the positive class weight to be 49.  Now the average weight from the positive class is 0.98 $\cdot$ 1 = 0.98, and the average weight from the negative class is 0.02 $\cdot$ 49 = 0.98.  The negative class weight multiplier is always 1.
#
# To incorporate the positive class weight in training, we multiply the loss by the positive weight whenever we see a positive class label.  For logistic regression, the weighted loss is:
#
# Weighted logistic regression:
#
# $$ \text{argmin}_{w_0, \mathbf{w}} \sum_{i=1}^N p y_i  \text{log}(\sigma(w_0 + \mathbf{x_i}^\intercal \mathbf{w})) - (1 - y_i) \text{log}(1 - \sigma(w_0 + \mathbf{x_i}^\intercal \mathbf{w})) $$
#
# $$ \text{where } p \text{ is the weight for the positive class.} $$
#
# The only difference between the weighted and unweighted logistic regression loss functions is the presense of the class weight, $p$ on the left-hand term in the loss.  Class weights in the hinge loss (SVM) classifier are applied in the same way.
#
# To apply class weights when training a model with linear learner, supply the weight for the positive class as a training parameter:

# %% [markdown]
#     positive_example_weight_mult=200,

# %% [markdown]
# Or to ask linear learner to calculate the positive class weight for you:

# %% [markdown]
#     positive_example_weight_mult='balanced',

# %% [markdown]
# ## Hands-on example: Detecting credit card fraud
#
# In this section, we'll look at a credit card fraud detection dataset.  The data set (Dal Pozzolo et al. 2015) was downloaded from [Kaggle](https://www.kaggle.com/mlg-ulb/creditcardfraud/data).  We have features and labels for over a quarter million credit card transactions, each of which is labeled as fraudulent or not fraudulent.  We'd like to train a model based on the features of these transactions so that we can predict risky or fraudulent transactions in the future.  This is a binary classification problem.
#
# We'll walk through training linear learner with various settings and deploying an inference endpoint.  We'll evaluate the quality of our models by hitting that endpoint with observations from the test set.  We can take the real-time predictions returned by the endpoint and evaluate them against the ground-truth labels in our test set.
#
# Next, we'll apply the linear learner threshold tuning functionality to get better precision without sacrificing recall.  Then, we'll push the precision even higher using the linear learner new class weights feature.  Because fraud can be extremely costly, we would prefer to have high recall, even if this means more false positives.  This is especially true if we are building a first line of defense, flagging potentially fraudulent transactions for further review before taking actions that affect customers.

# %% [markdown]
# First we'll do some preprocessing on this data set: we'll shuffle the examples and split them into train and test sets.  To run this under notebook under your own AWS account, you'll need to change the Amazon S3 locations.  First download the raw data from [Kaggle](https://www.kaggle.com/mlg-ulb/creditcardfraud/data) and upload to your SageMaker notebook instance (or wherever you're running this notebook).  Only 0.17% of the data have positive labels, making this a challenging classification problem.

# %%
import boto3
import io
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd 

import sagemaker
import sagemaker.amazon.common as smac
from sagemaker import get_execution_role
from sagemaker.predictor import csv_serializer, json_deserializer

# %%
# Set data locations
bucket = 'sagemaker-eu-west-1-586768923447'                        # replace this with your own bucket
prefix = 'sagemaker/DEMO-linear-learner-loss-weights'   # replace this with your own prefix
s3_train_key = '{}/train/recordio-pb-data'.format(prefix)
s3_train_path = os.path.join('s3://', bucket, s3_train_key)
local_raw_data = 'creditcard.csv.zip'
role = get_execution_role()

# %%
# Confirm access to s3 bucket
boto3.client('s3').download_file(bucket, 'creditcardfraud.zip', local_raw_data)

# %%
# Read the data, shuffle, and split into train and test sets, separating the labels (last column) from the features
raw_data = pd.read_csv(local_raw_data).as_matrix()
np.random.seed(0)
np.random.shuffle(raw_data)
train_size = int(raw_data.shape[0] * 0.7)
train_features  = raw_data[:train_size, :-1]
train_labels = raw_data[:train_size, -1]
test_features = raw_data[train_size:, :-1]
test_labels = raw_data[train_size:, -1]

# Convert the processed training data to protobuf and write to S3 for linear learner
vectors = np.array([t.tolist() for t in train_features]).astype('float32')
labels = np.array([t.tolist() for t in train_labels]).astype('float32')
buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, vectors, labels)
buf.seek(0)
boto3.resource('s3').Bucket(bucket).Object(s3_train_key).upload_fileobj(buf)

# %% [markdown]
# We'll wrap the model training setup in a convenience function that takes in the S3 location of the training data, the model hyperparameters that define our training job, and the S3 output path for model artifacts.  Inside the function, we'll hardcode the algorithm container, the number and type of EC2 instances to train on, and the input and output data formats.

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri

def predictor_from_hyperparams(s3_train_data, hyperparams, output_path):
    """
    Create an Estimator from the given hyperparams, fit to training data, and return a deployed predictor
    """
    # specify algorithm containers and instantiate an Estimator with given hyperparams
    container = get_image_uri(boto3.Session().region_name, 'linear-learner')

    linear = sagemaker.estimator.Estimator(container,
        role,
        train_instance_count=1,
        train_instance_type='ml.m4.xlarge',
        output_path=output_path,
        sagemaker_session=sagemaker.Session())
    linear.set_hyperparameters(**hyperparams)
    # train model
    linear.fit({'train': s3_train_data})
    # deploy a predictor
    linear_predictor = linear.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
    linear_predictor.content_type = 'text/csv'
    linear_predictor.serializer = csv_serializer
    linear_predictor.deserializer = json_deserializer
    return linear_predictor

# %% [markdown]
# And add another convenience function for setting up a hosting endpoint, making predictions, and evaluating the model.  To make predictions, we need to set up a model hosting endpoint.  Then we feed test features to the endpoint and receive predicted test labels.  To evaluate the models we create in this exercise, we'll capture predicted test labels and compare them to actuals using some common binary classification metrics.

# %%
def evaluate(linear_predictor, test_features, test_labels, model_name, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  Return binary classification metrics.
    """
    # split the test data set into 100 batches and evaluate using prediction endpoint
    prediction_batches = [linear_predictor.predict(batch)['predictions'] for batch in np.array_split(test_features, 100)]
    # parse raw predictions json to exctract predicted label
    test_preds = np.concatenate([np.array([x['predicted_label'] for x in batch]) for batch in prediction_batches])
    
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    f1 = 2 * precision * recall / (precision + recall)
    
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actuals'], colnames=['predictions']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print("{:<11} {:.3f}".format('F1:', f1))
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 'Precision': precision, 'Recall': recall, 'Accuracy': accuracy, 
             'F1': f1, 'Model': model_name}

# %% [markdown]
# And finally we'll add a convenience function to delete prediction endpoints after we're done with them:

# %%
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint))

# %% [markdown]
# Let's begin by training a binary classifier model with the linear learner default settings.  Note that we're setting the number of epochs to 40, which is much higher than the default of 10 epochs.  With early stopping, we don't have to worry about setting the number of epochs too high.  Linear learner will stop training automatically after the model has converged.

# %%
# Training a binary classifier with default settings: logistic regression
defaults_hyperparams = {
    'feature_dim': 30,
    'predictor_type': 'binary_classifier',
    'epochs': 40
}
defaults_output_path = 's3://{}/{}/defaults/output'.format(bucket, prefix)
defaults_predictor = predictor_from_hyperparams(s3_train_path, defaults_hyperparams, defaults_output_path)
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2019-05-05-19-45-37-403
# 2019-05-05 19:45:37 Starting - Starting the training job...
# 2019-05-05 19:45:38 Starting - Launching requested ML instances......
# 2019-05-05 19:46:41 Starting - Preparing the instances for training...
# 2019-05-05 19:47:33 Downloading - Downloading input data...
# 2019-05-05 19:47:42 Training - Downloading the training image...
# 2019-05-05 19:48:26 Training - Training image download completed. Training in progress.
# Docker entrypoint called with argument(s): train
# [05/05/2019 19:48:29 INFO 140162821031744] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [05/05/2019 19:48:29 INFO 140162821031744] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'40', u'feature_dim': u'30', u'predictor_type': u'binary_classifier'}
# [05/05/2019 19:48:29 INFO 140162821031744] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'40', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [05/05/2019 19:48:29 WARNING 140162821031744] Loggers have already been setup.
# Process 1 is a worker.
# [05/05/2019 19:48:29 INFO 140162821031744] Using default worker.
# [2019-05-05 19:48:29.107] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/train", "num_examples": 1000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [30], "storage_type": "dense"}]}
# [2019-05-05 19:48:29.139] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 0, "duration": 33, "num_examples": 1}
# [05/05/2019 19:48:29 INFO 140162821031744] Create Store: local
# [2019-05-05 19:48:29.217] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 1, "duration": 77, "num_examples": 11}
# [05/05/2019 19:48:29 INFO 140162821031744] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f79defe6ad0>
# [05/05/2019 19:48:29 INFO 140162821031744] Scaling model computed with parameters:
#  {'stdev_weight':
# [  4.71942188e+04   2.01291966e+00   1.69568098e+00   1.57379591e+00
#    1.42111158e+00   1.74640667e+00   1.51144338e+00   1.63385201e+00
#    1.13653934e+00   1.08314764e+00   1.06824124e+00   1.03516150e+00
#    1.01673567e+00   9.92477775e-01   9.78726447e-01   9.13698077e-01
#    8.90511751e-01   8.58795881e-01   8.44277263e-01   8.11051309e-01
#    9.23640847e-01   7.29950190e-01   7.28531599e-01   6.56139612e-01
#    6.05293095e-01   5.20700455e-01   4.88954067e-01   5.05282402e-01
#    3.77208292e-01   3.40401947e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [  9.41158750e+04  -2.09659096e-02   6.00883830e-03  -6.06044414e-05
#    1.07088813e-03   2.56213127e-03   1.28126498e-02   5.70237590e-03
#    1.37717789e-02   5.02825656e-04  -1.49376029e-02   8.31487868e-03
#    2.41851507e-04  -7.11433776e-03  -6.22152584e-03   1.35600369e-03
#   -3.61267186e-04   4.83268918e-03  -3.69541849e-05   1.13776792e-03
#   -9.44486167e-03  -6.55637588e-03  -1.03078522e-02  -2.02503870e-03
#    3.76771495e-04  -1.49243438e-04   7.94459879e-03   1.23333558e-02
#    2.39625806e-03   8.90791397e+01]
# <NDArray 30 @cpu(0)>}
# [05/05/2019 19:48:29 INFO 140162821031744] nvidia-smi took: 0.033618927002 secs to identify 0 gpus
# [05/05/2019 19:48:29 INFO 140162821031744] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1557085709.337846, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1557085709.337779}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12035683542759575, "sum": 0.12035683542759575, "min": 0.12035683542759575}}, "EndTime": 1557085716.093646, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.093557}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11762137596092033, "sum": 0.11762137596092033, "min": 0.11762137596092033}}, "EndTime": 1557085716.093755, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.093737}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12017832863390746, "sum": 0.12017832863390746, "min": 0.12017832863390746}}, "EndTime": 1557085716.093817, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.093804}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11787534816301048, "sum": 0.11787534816301048, "min": 0.11787534816301048}}, "EndTime": 1557085716.093872, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.09386}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012322734019452303, "sum": 0.012322734019452303, "min": 0.012322734019452303}}, "EndTime": 1557085716.093922, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.09391}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01278103816205982, "sum": 0.01278103816205982, "min": 0.01278103816205982}}, "EndTime": 1557085716.093971, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.093959}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012255296912100446, "sum": 0.012255296912100446, "min": 0.012255296912100446}}, "EndTime": 1557085716.094014, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094003}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012476920656784995, "sum": 0.012476920656784995, "min": 0.012476920656784995}}, "EndTime": 1557085716.094056, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094046}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1201731047127115, "sum": 0.1201731047127115, "min": 0.1201731047127115}}, "EndTime": 1557085716.094098, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094088}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11779978965874294, "sum": 0.11779978965874294, "min": 0.11779978965874294}}, "EndTime": 1557085716.094154, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094141}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12043298052303755, "sum": 0.12043298052303755, "min": 0.12043298052303755}}, "EndTime": 1557085716.094202, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.09419}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11784271825857498, "sum": 0.11784271825857498, "min": 0.11784271825857498}}, "EndTime": 1557085716.094245, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094235}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01312513770455092, "sum": 0.01312513770455092, "min": 0.01312513770455092}}, "EndTime": 1557085716.094287, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094277}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012790858735016841, "sum": 0.012790858735016841, "min": 0.012790858735016841}}, "EndTime": 1557085716.094329, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094319}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013154447582442707, "sum": 0.013154447582442707, "min": 0.013154447582442707}}, "EndTime": 1557085716.094377, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094366}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012830747917594023, "sum": 0.012830747917594023, "min": 0.012830747917594023}}, "EndTime": 1557085716.094421, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094411}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12255334890547709, "sum": 0.12255334890547709, "min": 0.12255334890547709}}, "EndTime": 1557085716.094466, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094455}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11991955161933324, "sum": 0.11991955161933324, "min": 0.11991955161933324}}, "EndTime": 1557085716.09451, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094499}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12265944444474264, "sum": 0.12265944444474264, "min": 0.12265944444474264}}, "EndTime": 1557085716.094555, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094543}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11997546653172479, "sum": 0.11997546653172479, "min": 0.11997546653172479}}, "EndTime": 1557085716.0946, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094589}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019124138720071494, "sum": 0.019124138720071494, "min": 0.019124138720071494}}, "EndTime": 1557085716.094646, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094635}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019075273148640617, "sum": 0.019075273148640617, "min": 0.019075273148640617}}, "EndTime": 1557085716.094692, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094681}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019185221950425276, "sum": 0.019185221950425276, "min": 0.019185221950425276}}, "EndTime": 1557085716.094735, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094724}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01911186106899875, "sum": 0.01911186106899875, "min": 0.01911186106899875}}, "EndTime": 1557085716.094783, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.09477}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12319823741433608, "sum": 0.12319823741433608, "min": 0.12319823741433608}}, "EndTime": 1557085716.094833, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094821}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1207087927008394, "sum": 0.1207087927008394, "min": 0.1207087927008394}}, "EndTime": 1557085716.094877, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094866}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12333532436888421, "sum": 0.12333532436888421, "min": 0.12333532436888421}}, "EndTime": 1557085716.094921, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.09491}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1207283185163335, "sum": 0.1207283185163335, "min": 0.1207283185163335}}, "EndTime": 1557085716.094974, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.094959}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020070784585147945, "sum": 0.020070784585147945, "min": 0.020070784585147945}}, "EndTime": 1557085716.095021, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.09501}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020162629977430232, "sum": 0.020162629977430232, "min": 0.020162629977430232}}, "EndTime": 1557085716.095067, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.095056}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0201171408007717, "sum": 0.0201171408007717, "min": 0.0201171408007717}}, "EndTime": 1557085716.095116, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.095103}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02016482493854198, "sum": 0.02016482493854198, "min": 0.02016482493854198}}, "EndTime": 1557085716.095166, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085716.095154}
#
# [05/05/2019 19:48:36 INFO 140162821031744] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.120356835428
# [05/05/2019 19:48:36 INFO 140162821031744] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.0122552969121
# [05/05/2019 19:48:36 INFO 140162821031744] Epoch 0: Loss improved. Updating best model
# [05/05/2019 19:48:36 INFO 140162821031744] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1557085716.098492, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557085709.338112}
#
# [05/05/2019 19:48:36 INFO 140162821031744] #throughput_metric: host=algo-1, train throughput=29489.5006778 records/second
# [2019-05-05 19:48:36.098] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 2, "duration": 6760, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01693362826917639, "sum": 0.01693362826917639, "min": 0.01693362826917639}}, "EndTime": 1557085723.028, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.027935}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01493441298019946, "sum": 0.01493441298019946, "min": 0.01493441298019946}}, "EndTime": 1557085723.028079, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028065}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016916529439801545, "sum": 0.016916529439801545, "min": 0.016916529439801545}}, "EndTime": 1557085723.028118, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028109}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014954894904515252, "sum": 0.014954894904515252, "min": 0.014954894904515252}}, "EndTime": 1557085723.028197, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028176}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005533096842729865, "sum": 0.005533096842729865, "min": 0.005533096842729865}}, "EndTime": 1557085723.028252, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028237}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0063248079688704795, "sum": 0.0063248079688704795, "min": 0.0063248079688704795}}, "EndTime": 1557085723.028306, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028291}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0054876789942608405, "sum": 0.0054876789942608405, "min": 0.0054876789942608405}}, "EndTime": 1557085723.028371, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028361}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005895276856107927, "sum": 0.005895276856107927, "min": 0.005895276856107927}}, "EndTime": 1557085723.028402, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028394}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.017071099458627365, "sum": 0.017071099458627365, "min": 0.017071099458627365}}, "EndTime": 1557085723.02843, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028423}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015126742930867564, "sum": 0.015126742930867564, "min": 0.015126742930867564}}, "EndTime": 1557085723.028459, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028452}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.017088333072374815, "sum": 0.017088333072374815, "min": 0.017088333072374815}}, "EndTime": 1557085723.028487, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.02848}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015128407150057692, "sum": 0.015128407150057692, "min": 0.015128407150057692}}, "EndTime": 1557085723.028536, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028525}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006067627504093563, "sum": 0.006067627504093563, "min": 0.006067627504093563}}, "EndTime": 1557085723.028566, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028559}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005882761371045856, "sum": 0.005882761371045856, "min": 0.005882761371045856}}, "EndTime": 1557085723.028595, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028587}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006112182712584883, "sum": 0.006112182712584883, "min": 0.006112182712584883}}, "EndTime": 1557085723.028638, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028624}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005824190800064173, "sum": 0.005824190800064173, "min": 0.005824190800064173}}, "EndTime": 1557085723.028696, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028681}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02100562026632491, "sum": 0.02100562026632491, "min": 0.02100562026632491}}, "EndTime": 1557085723.028746, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028732}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019215155452939135, "sum": 0.019215155452939135, "min": 0.019215155452939135}}, "EndTime": 1557085723.028795, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028781}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021010461701819645, "sum": 0.021010461701819645, "min": 0.021010461701819645}}, "EndTime": 1557085723.028853, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028839}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0192125394044809, "sum": 0.0192125394044809, "min": 0.0192125394044809}}, "EndTime": 1557085723.028904, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028889}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011495619112522757, "sum": 0.011495619112522757, "min": 0.011495619112522757}}, "EndTime": 1557085723.028948, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028935}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01150003069609254, "sum": 0.01150003069609254, "min": 0.01150003069609254}}, "EndTime": 1557085723.029001, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.028986}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011505962901378996, "sum": 0.011505962901378996, "min": 0.011505962901378996}}, "EndTime": 1557085723.029054, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.029039}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011503141617655156, "sum": 0.011503141617655156, "min": 0.011503141617655156}}, "EndTime": 1557085723.029103, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.029089}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021785617574375478, "sum": 0.021785617574375478, "min": 0.021785617574375478}}, "EndTime": 1557085723.029162, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.029147}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020012201443389433, "sum": 0.020012201443389433, "min": 0.020012201443389433}}, "EndTime": 1557085723.029218, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.029204}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02179621315960908, "sum": 0.02179621315960908, "min": 0.02179621315960908}}, "EndTime": 1557085723.029295, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.029279}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020010725433502963, "sum": 0.020010725433502963, "min": 0.020010725433502963}}, "EndTime": 1557085723.029351, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.029336}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012480857162619355, "sum": 0.012480857162619355, "min": 0.012480857162619355}}, "EndTime": 1557085723.029403, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.029388}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012483165198235056, "sum": 0.012483165198235056, "min": 0.012483165198235056}}, "EndTime": 1557085723.029476, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.029443}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012479858870482325, "sum": 0.012479858870482325, "min": 0.012479858870482325}}, "EndTime": 1557085723.029536, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.02952}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012482986148278318, "sum": 0.012482986148278318, "min": 0.012482986148278318}}, "EndTime": 1557085723.029592, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085723.029577}
#
# [05/05/2019 19:48:43 INFO 140162821031744] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.0169336282692
# [05/05/2019 19:48:43 INFO 140162821031744] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.00548767899426
# [05/05/2019 19:48:43 INFO 140162821031744] Epoch 1: Loss improved. Updating best model
# [05/05/2019 19:48:43 INFO 140162821031744] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1557085723.032363, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557085716.098804}
#
# [05/05/2019 19:48:43 INFO 140162821031744] #throughput_metric: host=algo-1, train throughput=28752.9891439 records/second
# [2019-05-05 19:48:43.032] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 3, "duration": 6933, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010280890280277885, "sum": 0.010280890280277885, "min": 0.010280890280277885}}, "EndTime": 1557085728.897031, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.896963}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008703173548731971, "sum": 0.008703173548731971, "min": 0.008703173548731971}}, "EndTime": 1557085728.897115, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.897101}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010268610419939511, "sum": 0.010268610419939511, "min": 0.010268610419939511}}, "EndTime": 1557085728.897186, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.897169}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008716777494804344, "sum": 0.008716777494804344, "min": 0.008716777494804344}}, "EndTime": 1557085728.897298, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.897229}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005077203194549934, "sum": 0.005077203194549934, "min": 0.005077203194549934}}, "EndTime": 1557085728.897442, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.89742}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005960388685440897, "sum": 0.005960388685440897, "min": 0.005960388685440897}}, "EndTime": 1557085728.897499, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.897487}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005005124478483919, "sum": 0.005005124478483919, "min": 0.005005124478483919}}, "EndTime": 1557085728.897561, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.897544}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00613126052189712, "sum": 0.00613126052189712, "min": 0.00613126052189712}}, "EndTime": 1557085728.897622, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.897606}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010545964197896832, "sum": 0.010545964197896832, "min": 0.010545964197896832}}, "EndTime": 1557085728.89768, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.897663}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00904736291942884, "sum": 0.00904736291942884, "min": 0.00904736291942884}}, "EndTime": 1557085728.897738, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.897722}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010554662002390953, "sum": 0.010554662002390953, "min": 0.010554662002390953}}, "EndTime": 1557085728.897792, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.897775}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.009047675942655783, "sum": 0.009047675942655783, "min": 0.009047675942655783}}, "EndTime": 1557085728.897858, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.897843}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006062194085600388, "sum": 0.006062194085600388, "min": 0.006062194085600388}}, "EndTime": 1557085728.897914, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.897899}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005814293683473789, "sum": 0.005814293683473789, "min": 0.005814293683473789}}, "EndTime": 1557085728.897971, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.897956}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006061888689671329, "sum": 0.006061888689671329, "min": 0.006061888689671329}}, "EndTime": 1557085728.898033, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898017}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006016780574717114, "sum": 0.006016780574717114, "min": 0.006016780574717114}}, "EndTime": 1557085728.898089, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898073}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015224682985238694, "sum": 0.015224682985238694, "min": 0.015224682985238694}}, "EndTime": 1557085728.898144, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898129}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01397782376064128, "sum": 0.01397782376064128, "min": 0.01397782376064128}}, "EndTime": 1557085728.898199, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898184}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015228877695361574, "sum": 0.015228877695361574, "min": 0.015228877695361574}}, "EndTime": 1557085728.898256, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898241}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013976303852982257, "sum": 0.013976303852982257, "min": 0.013976303852982257}}, "EndTime": 1557085728.898312, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898297}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011517464831246802, "sum": 0.011517464831246802, "min": 0.011517464831246802}}, "EndTime": 1557085728.898368, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898353}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011523272909111712, "sum": 0.011523272909111712, "min": 0.011523272909111712}}, "EndTime": 1557085728.898425, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898409}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011522903874291847, "sum": 0.011522903874291847, "min": 0.011522903874291847}}, "EndTime": 1557085728.898481, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898465}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011532373850669094, "sum": 0.011532373850669094, "min": 0.011532373850669094}}, "EndTime": 1557085728.89854, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898523}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016013618215244618, "sum": 0.016013618215244618, "min": 0.016013618215244618}}, "EndTime": 1557085728.898596, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898581}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01478147773646829, "sum": 0.01478147773646829, "min": 0.01478147773646829}}, "EndTime": 1557085728.898652, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898637}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016018314795278425, "sum": 0.016018314795278425, "min": 0.016018314795278425}}, "EndTime": 1557085728.898707, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898692}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014780291039740021, "sum": 0.014780291039740021, "min": 0.014780291039740021}}, "EndTime": 1557085728.898765, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898749}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012480147539071701, "sum": 0.012480147539071701, "min": 0.012480147539071701}}, "EndTime": 1557085728.898819, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898803}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012490562180178848, "sum": 0.012490562180178848, "min": 0.012490562180178848}}, "EndTime": 1557085728.898874, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898859}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012479020789040993, "sum": 0.012479020789040993, "min": 0.012479020789040993}}, "EndTime": 1557085728.898926, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898914}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012491502482088367, "sum": 0.012491502482088367, "min": 0.012491502482088367}}, "EndTime": 1557085728.898978, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085728.898963}
#
# [05/05/2019 19:48:48 INFO 140162821031744] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.0102808902803
# [05/05/2019 19:48:48 INFO 140162821031744] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.00500512447848
# [05/05/2019 19:48:48 INFO 140162821031744] Epoch 2: Loss improved. Updating best model
# [05/05/2019 19:48:48 INFO 140162821031744] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1557085728.901849, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557085723.032645}
#
# [05/05/2019 19:48:48 INFO 140162821031744] #throughput_metric: host=algo-1, train throughput=33966.9876816 records/second
# [2019-05-05 19:48:48.902] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 4, "duration": 5869, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.007993003969815508, "sum": 0.007993003969815508, "min": 0.007993003969815508}}, "EndTime": 1557085735.283805, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557085735.283738}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006652505127029802, "sum": 0.006652505127029802, "min": 0.006652505127029802}}, "EndTime": 1557085735.283889, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557085735.283875}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.007985756025841487, "sum": 0.007985756025841487, "min": 0.007985756025841487}}, "EndTime": 1557085735.283929, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557085735.28392}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0066610379518576, "sum": 0.0066610379518576, "min": 0.0066610379518576}}, "EndTime": 1557085735.283972, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557085735.283957}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004913139717063712, "sum": 0.004913139717063712, "min": 0.004913139717063712}}, "EndTime": 1557085735.284024, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557085735.284012}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006007583376525635, "sum": 0.006007583376525635, "min": 0.006007583376525635}}, "EndTime": 1557085735.284057, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557085735.284049}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004056161796178051, "sum": 0.004056161796178051, "min": 0.004056161796178051}}, "EndTime": 1557085889.709993, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.709975}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00397384125009254, "sum": 0.00397384125009254, "min": 0.00397384125009254}}, "EndTime": 1557085889.710055, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710038}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005190758120848905, "sum": 0.005190758120848905, "min": 0.005190758120848905}}, "EndTime": 1557085889.710115, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710098}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.003973343082408809, "sum": 0.003973343082408809, "min": 0.003973343082408809}}, "EndTime": 1557085889.710173, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710156}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005208741483826134, "sum": 0.005208741483826134, "min": 0.005208741483826134}}, "EndTime": 1557085889.710232, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710216}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0053864457403595125, "sum": 0.0053864457403595125, "min": 0.0053864457403595125}}, "EndTime": 1557085889.710293, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710276}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005139727617328491, "sum": 0.005139727617328491, "min": 0.005139727617328491}}, "EndTime": 1557085889.710353, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710337}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00533573668027044, "sum": 0.00533573668027044, "min": 0.00533573668027044}}, "EndTime": 1557085889.710413, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710397}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005139719408960198, "sum": 0.005139719408960198, "min": 0.005139719408960198}}, "EndTime": 1557085889.710472, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710456}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005093681085049807, "sum": 0.005093681085049807, "min": 0.005093681085049807}}, "EndTime": 1557085889.710535, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710519}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006105666607768092, "sum": 0.006105666607768092, "min": 0.006105666607768092}}, "EndTime": 1557085889.710597, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710581}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005093690500487035, "sum": 0.005093690500487035, "min": 0.005093690500487035}}, "EndTime": 1557085889.710655, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.71064}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006105792368925995, "sum": 0.006105792368925995, "min": 0.006105792368925995}}, "EndTime": 1557085889.710715, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710699}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011675228393257563, "sum": 0.011675228393257563, "min": 0.011675228393257563}}, "EndTime": 1557085889.710777, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710761}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011661708266890827, "sum": 0.011661708266890827, "min": 0.011661708266890827}}, "EndTime": 1557085889.710835, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710819}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0116671499391297, "sum": 0.0116671499391297, "min": 0.0116671499391297}}, "EndTime": 1557085889.710894, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710877}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011661707406067968, "sum": 0.011661707406067968, "min": 0.011661707406067968}}, "EndTime": 1557085889.710952, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710936}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011660580781836006, "sum": 0.011660580781836006, "min": 0.011660580781836006}}, "EndTime": 1557085889.711011, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.710996}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01165691210426877, "sum": 0.01165691210426877, "min": 0.01165691210426877}}, "EndTime": 1557085889.711067, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.711052}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011660579335749448, "sum": 0.011660579335749448, "min": 0.011660579335749448}}, "EndTime": 1557085889.711125, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.711109}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011656674038824723, "sum": 0.011656674038824723, "min": 0.011656674038824723}}, "EndTime": 1557085889.711182, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.711166}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012488596610687486, "sum": 0.012488596610687486, "min": 0.012488596610687486}}, "EndTime": 1557085889.711239, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.711224}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012462469092565565, "sum": 0.012462469092565565, "min": 0.012462469092565565}}, "EndTime": 1557085889.711301, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.711284}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01247654838897475, "sum": 0.01247654838897475, "min": 0.01247654838897475}}, "EndTime": 1557085889.71137, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.711353}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012463161851892519, "sum": 0.012463161851892519, "min": 0.012463161851892519}}, "EndTime": 1557085889.711431, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.711415}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012459224031199163, "sum": 0.012459224031199163, "min": 0.012459224031199163}}, "EndTime": 1557085889.711493, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.711476}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012602293426067985, "sum": 0.012602293426067985, "min": 0.012602293426067985}}, "EndTime": 1557085889.711579, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.71156}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012459361534621847, "sum": 0.012459361534621847, "min": 0.012459361534621847}}, "EndTime": 1557085889.71165, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.711633}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012603153902981149, "sum": 0.012603153902981149, "min": 0.012603153902981149}}, "EndTime": 1557085889.711712, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085889.711696}
#
# [05/05/2019 19:51:29 INFO 140162821031744] #quality_metric: host=algo-1, epoch=27, train binary_classification_cross_entropy_objective <loss>=0.00461571828924
# [05/05/2019 19:51:29 INFO 140162821031744] #early_stopping_criteria_metric: host=algo-1, epoch=27, criteria=binary_classification_cross_entropy_objective, value=0.00397334308241
# [05/05/2019 19:51:29 INFO 140162821031744] Early stop condition met. Stopping training.
# [05/05/2019 19:51:29 INFO 140162821031744] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 5612, "sum": 5612.0, "min": 5612}, "Total Records Seen": {"count": 1, "max": 5594192, "sum": 5594192.0, "min": 5594192}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 30, "sum": 30.0, "min": 30}}, "EndTime": 1557085889.713961, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557085883.367746}
#
# [05/05/2019 19:51:29 INFO 140162821031744] #throughput_metric: host=algo-1, train throughput=31413.9873643 records/second
# [05/05/2019 19:51:29 WARNING 140162821031744] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [05/05/2019 19:51:29 WARNING 140162821031744] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-05-05 19:51:29.714] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 29, "duration": 6346, "num_examples": 200}
# [2019-05-05 19:51:29.720] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 30, "duration": 6, "num_examples": 1}
# [2019-05-05 19:51:30.537] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 31, "duration": 813, "num_examples": 200}
# [05/05/2019 19:51:31 INFO 140162821031744] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.0039684858283528081)
# [05/05/2019 19:51:31 INFO 140162821031744] #train_score (algo-1) : ('binary_classification_accuracy', 0.99925262334222831)
# [05/05/2019 19:51:31 INFO 140162821031744] #train_score (algo-1) : ('binary_f_1.000', 0.7561374795417348)
# [05/05/2019 19:51:31 INFO 140162821031744] #train_score (algo-1) : ('precision', 0.843065693430657)
# [05/05/2019 19:51:31 INFO 140162821031744] #train_score (algo-1) : ('recall', 0.685459940652819)
# [05/05/2019 19:51:31 INFO 140162821031744] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.00396848582835
# [05/05/2019 19:51:31 INFO 140162821031744] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.999252623342
# [05/05/2019 19:51:31 INFO 140162821031744] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.756137479542
# [05/05/2019 19:51:31 INFO 140162821031744] #quality_metric: host=algo-1, train precision <score>=0.843065693431
# [05/05/2019 19:51:31 INFO 140162821031744] #quality_metric: host=algo-1, train recall <score>=0.685459940653
# [05/05/2019 19:51:31 INFO 140162821031744] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [05/05/2019 19:51:31 INFO 140162821031744] Saved checkpoint to "/tmp/tmp5bsWqZ/mx-mod-0000.params"
# [05/05/2019 19:51:31 INFO 140162821031744] Test data is not provided.
# [2019-05-05 19:51:31.295] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 32, "duration": 758, "num_examples": 200}
# [2019-05-05 19:51:31.295] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "duration": 182043, "num_epochs": 33, "num_examples": 6013}
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 182278.12695503235, "sum": 182278.12695503235, "min": 182278.12695503235}, "finalize.time": {"count": 1, "max": 1573.786973953247, "sum": 1573.786973953247, "min": 1573.786973953247}, "initialize.time": {"count": 1, "max": 225.73280334472656, "sum": 225.73280334472656, "min": 225.73280334472656}, "check_early_stopping.time": {"count": 28, "max": 1.1320114135742188, "sum": 19.564390182495117, "min": 0.17881393432617188}, "setuptime": {"count": 1, "max": 17.93694496154785, "sum": 17.93694496154785, "min": 17.93694496154785}, "update.time": {"count": 28, "max": 6933.395147323608, "sum": 180362.6344203949, "min": 5869.03715133667}, "epochs": {"count": 1, "max": 40, "sum": 40.0, "min": 40}}, "EndTime": 1557085891.296102, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1557085709.10538}
#
#
# 2019-05-05 19:51:42 Completed - Training job completed
# INFO:sagemaker:Creating model with name: linear-learner-2019-05-05-19-52-21-431
# Billable seconds: 249
# INFO:sagemaker:Creating endpoint with name linear-learner-2019-05-05-19-45-37-403
# ---------------------------------------------------------------------------------------!

# %% [markdown]
# And now we'll produce a model with a threshold tuned for the best possible precision with recall fixed at 90%:

# %%
# Training a binary classifier with automated threshold tuning
autothresh_hyperparams = {
    'feature_dim': 30,
    'predictor_type': 'binary_classifier',
    'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 
    'target_recall': 0.9,
    'epochs': 40
}
autothresh_output_path = 's3://{}/{}/autothresh/output'.format(bucket, prefix)
autothresh_predictor = predictor_from_hyperparams(s3_train_path, autothresh_hyperparams, autothresh_output_path)
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2019-05-05-19-59-41-755
# 2019-05-05 19:59:41 Starting - Starting the training job...
# 2019-05-05 19:59:43 Starting - Launching requested ML instances......
# 2019-05-05 20:00:48 Starting - Preparing the instances for training......
# 2019-05-05 20:01:59 Downloading - Downloading input data
# 2019-05-05 20:01:59 Training - Downloading the training image...
# 2019-05-05 20:02:27 Training - Training image download completed. Training in progress.
# Docker entrypoint called with argument(s): train
# [05/05/2019 20:02:30 INFO 139931280869184] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [05/05/2019 20:02:30 INFO 139931280869184] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'40', u'target_recall': u'0.9', u'feature_dim': u'30', u'predictor_type': u'binary_classifier', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall'}
# [05/05/2019 20:02:30 INFO 139931280869184] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'40', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [05/05/2019 20:02:30 WARNING 139931280869184] Loggers have already been setup.
# Process 1 is a worker.
# [05/05/2019 20:02:30 INFO 139931280869184] Using default worker.
# [2019-05-05 20:02:30.453] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/train", "num_examples": 1000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [30], "storage_type": "dense"}]}
# [2019-05-05 20:02:30.487] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 0, "duration": 35, "num_examples": 1}
# [05/05/2019 20:02:30 INFO 139931280869184] Create Store: local
# [2019-05-05 20:02:30.567] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 1, "duration": 78, "num_examples": 11}
# [05/05/2019 20:02:30 INFO 139931280869184] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f43f69a7ad0>
# [05/05/2019 20:02:30 INFO 139931280869184] Scaling model computed with parameters:
#  {'stdev_weight':
# [  4.71942188e+04   2.01291966e+00   1.69568098e+00   1.57379591e+00
#    1.42111158e+00   1.74640667e+00   1.51144338e+00   1.63385201e+00
#    1.13653934e+00   1.08314764e+00   1.06824124e+00   1.03516150e+00
#    1.01673567e+00   9.92477775e-01   9.78726447e-01   9.13698077e-01
#    8.90511751e-01   8.58795881e-01   8.44277263e-01   8.11051309e-01
#    9.23640847e-01   7.29950190e-01   7.28531599e-01   6.56139612e-01
#    6.05293095e-01   5.20700455e-01   4.88954067e-01   5.05282402e-01
#    3.77208292e-01   3.40401947e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [  9.41158750e+04  -2.09659096e-02   6.00883830e-03  -6.06044414e-05
#    1.07088813e-03   2.56213127e-03   1.28126498e-02   5.70237590e-03
#    1.37717789e-02   5.02825656e-04  -1.49376029e-02   8.31487868e-03
#    2.41851507e-04  -7.11433776e-03  -6.22152584e-03   1.35600369e-03
#   -3.61267186e-04   4.83268918e-03  -3.69541849e-05   1.13776792e-03
#   -9.44486167e-03  -6.55637588e-03  -1.03078522e-02  -2.02503870e-03
#    3.76771495e-04  -1.49243438e-04   7.94459879e-03   1.23333558e-02
#    2.39625806e-03   8.90791397e+01]
# <NDArray 30 @cpu(0)>}
# [05/05/2019 20:02:30 INFO 139931280869184] nvidia-smi took: 0.0251779556274 secs to identify 0 gpus
# [05/05/2019 20:02:30 INFO 139931280869184] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1557086550.684243, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1557086550.684202}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12035683542759575, "sum": 0.12035683542759575, "min": 0.12035683542759575}}, "EndTime": 1557086557.242116, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242017}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11762137596092033, "sum": 0.11762137596092033, "min": 0.11762137596092033}}, "EndTime": 1557086557.242237, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242219}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12017832863390746, "sum": 0.12017832863390746, "min": 0.12017832863390746}}, "EndTime": 1557086557.242299, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242286}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11787534816301048, "sum": 0.11787534816301048, "min": 0.11787534816301048}}, "EndTime": 1557086557.242346, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242334}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012322734019452303, "sum": 0.012322734019452303, "min": 0.012322734019452303}}, "EndTime": 1557086557.24239, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242379}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01278103816205982, "sum": 0.01278103816205982, "min": 0.01278103816205982}}, "EndTime": 1557086557.242434, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242423}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012255296912100446, "sum": 0.012255296912100446, "min": 0.012255296912100446}}, "EndTime": 1557086557.242477, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242466}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012476920656784995, "sum": 0.012476920656784995, "min": 0.012476920656784995}}, "EndTime": 1557086557.24252, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242508}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1201731047127115, "sum": 0.1201731047127115, "min": 0.1201731047127115}}, "EndTime": 1557086557.242563, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242552}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11779978965874294, "sum": 0.11779978965874294, "min": 0.11779978965874294}}, "EndTime": 1557086557.242618, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242605}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12043298052303755, "sum": 0.12043298052303755, "min": 0.12043298052303755}}, "EndTime": 1557086557.242671, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242658}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11784271825857498, "sum": 0.11784271825857498, "min": 0.11784271825857498}}, "EndTime": 1557086557.242723, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242711}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01312513770455092, "sum": 0.01312513770455092, "min": 0.01312513770455092}}, "EndTime": 1557086557.242775, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242762}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012790858735016841, "sum": 0.012790858735016841, "min": 0.012790858735016841}}, "EndTime": 1557086557.242826, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242814}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013154447582442707, "sum": 0.013154447582442707, "min": 0.013154447582442707}}, "EndTime": 1557086557.242881, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242869}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012830747917594023, "sum": 0.012830747917594023, "min": 0.012830747917594023}}, "EndTime": 1557086557.242934, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242922}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12255334890547709, "sum": 0.12255334890547709, "min": 0.12255334890547709}}, "EndTime": 1557086557.24298, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.242969}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11991955161933324, "sum": 0.11991955161933324, "min": 0.11991955161933324}}, "EndTime": 1557086557.243031, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243019}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12265944444474264, "sum": 0.12265944444474264, "min": 0.12265944444474264}}, "EndTime": 1557086557.243077, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243065}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11997546653172479, "sum": 0.11997546653172479, "min": 0.11997546653172479}}, "EndTime": 1557086557.243126, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243114}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019124138720071494, "sum": 0.019124138720071494, "min": 0.019124138720071494}}, "EndTime": 1557086557.243176, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243165}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019075273148640617, "sum": 0.019075273148640617, "min": 0.019075273148640617}}, "EndTime": 1557086557.243226, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243214}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019185221950425276, "sum": 0.019185221950425276, "min": 0.019185221950425276}}, "EndTime": 1557086557.243319, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243299}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01911186106899875, "sum": 0.01911186106899875, "min": 0.01911186106899875}}, "EndTime": 1557086557.243387, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243374}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12319823741433608, "sum": 0.12319823741433608, "min": 0.12319823741433608}}, "EndTime": 1557086557.243433, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243422}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1207087927008394, "sum": 0.1207087927008394, "min": 0.1207087927008394}}, "EndTime": 1557086557.243476, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243465}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12333532436888421, "sum": 0.12333532436888421, "min": 0.12333532436888421}}, "EndTime": 1557086557.243522, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243509}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1207283185163335, "sum": 0.1207283185163335, "min": 0.1207283185163335}}, "EndTime": 1557086557.243565, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243552}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020070784585147945, "sum": 0.020070784585147945, "min": 0.020070784585147945}}, "EndTime": 1557086557.243605, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243596}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020162629977430232, "sum": 0.020162629977430232, "min": 0.020162629977430232}}, "EndTime": 1557086557.243635, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243627}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0201171408007717, "sum": 0.0201171408007717, "min": 0.0201171408007717}}, "EndTime": 1557086557.243663, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243656}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02016482493854198, "sum": 0.02016482493854198, "min": 0.02016482493854198}}, "EndTime": 1557086557.243692, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086557.243684}
#
# [05/05/2019 20:02:37 INFO 139931280869184] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.120356835428
# [05/05/2019 20:02:37 INFO 139931280869184] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.0122552969121
# [05/05/2019 20:02:37 INFO 139931280869184] Epoch 0: Loss improved. Updating best model
# [05/05/2019 20:02:37 INFO 139931280869184] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1557086557.247237, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557086550.684486}
#
# [05/05/2019 20:02:37 INFO 139931280869184] #throughput_metric: host=algo-1, train throughput=30377.5456988 records/second
# [2019-05-05 20:02:37.247] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 2, "duration": 6562, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01693362826917639, "sum": 0.01693362826917639, "min": 0.01693362826917639}}, "EndTime": 1557086563.99191, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.991842}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01493441298019946, "sum": 0.01493441298019946, "min": 0.01493441298019946}}, "EndTime": 1557086563.992003, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.991982}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016916529439801545, "sum": 0.016916529439801545, "min": 0.016916529439801545}}, "EndTime": 1557086563.992063, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992046}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014954894904515252, "sum": 0.014954894904515252, "min": 0.014954894904515252}}, "EndTime": 1557086563.992116, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992105}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005533096842729865, "sum": 0.005533096842729865, "min": 0.005533096842729865}}, "EndTime": 1557086563.992169, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992155}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0063248079688704795, "sum": 0.0063248079688704795, "min": 0.0063248079688704795}}, "EndTime": 1557086563.992218, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992205}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0054876789942608405, "sum": 0.0054876789942608405, "min": 0.0054876789942608405}}, "EndTime": 1557086563.992271, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992257}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005895276856107927, "sum": 0.005895276856107927, "min": 0.005895276856107927}}, "EndTime": 1557086563.99232, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992307}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.017071099458627365, "sum": 0.017071099458627365, "min": 0.017071099458627365}}, "EndTime": 1557086563.99237, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992357}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015126742930867564, "sum": 0.015126742930867564, "min": 0.015126742930867564}}, "EndTime": 1557086563.992418, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992405}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.017088333072374815, "sum": 0.017088333072374815, "min": 0.017088333072374815}}, "EndTime": 1557086563.992466, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992453}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015128407150057692, "sum": 0.015128407150057692, "min": 0.015128407150057692}}, "EndTime": 1557086563.992515, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992502}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006067627504093563, "sum": 0.006067627504093563, "min": 0.006067627504093563}}, "EndTime": 1557086563.992564, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.99255}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005882761371045856, "sum": 0.005882761371045856, "min": 0.005882761371045856}}, "EndTime": 1557086563.992625, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992604}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006112182712584883, "sum": 0.006112182712584883, "min": 0.006112182712584883}}, "EndTime": 1557086563.992688, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992671}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005824190800064173, "sum": 0.005824190800064173, "min": 0.005824190800064173}}, "EndTime": 1557086563.992741, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992728}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02100562026632491, "sum": 0.02100562026632491, "min": 0.02100562026632491}}, "EndTime": 1557086563.992791, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992778}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019215155452939135, "sum": 0.019215155452939135, "min": 0.019215155452939135}}, "EndTime": 1557086563.99284, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992827}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021010461701819645, "sum": 0.021010461701819645, "min": 0.021010461701819645}}, "EndTime": 1557086563.99289, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992877}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0192125394044809, "sum": 0.0192125394044809, "min": 0.0192125394044809}}, "EndTime": 1557086563.99294, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992927}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011495619112522757, "sum": 0.011495619112522757, "min": 0.011495619112522757}}, "EndTime": 1557086563.99299, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.992977}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01150003069609254, "sum": 0.01150003069609254, "min": 0.01150003069609254}}, "EndTime": 1557086563.993039, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.993026}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011505962901378996, "sum": 0.011505962901378996, "min": 0.011505962901378996}}, "EndTime": 1557086563.993092, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.993078}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011503141617655156, "sum": 0.011503141617655156, "min": 0.011503141617655156}}, "EndTime": 1557086563.993142, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.993129}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021785617574375478, "sum": 0.021785617574375478, "min": 0.021785617574375478}}, "EndTime": 1557086563.99319, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.993177}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020012201443389433, "sum": 0.020012201443389433, "min": 0.020012201443389433}}, "EndTime": 1557086563.993241, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.993228}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02179621315960908, "sum": 0.02179621315960908, "min": 0.02179621315960908}}, "EndTime": 1557086563.993289, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.993277}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020010725433502963, "sum": 0.020010725433502963, "min": 0.020010725433502963}}, "EndTime": 1557086563.993338, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.993326}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012480857162619355, "sum": 0.012480857162619355, "min": 0.012480857162619355}}, "EndTime": 1557086563.993392, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.993378}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012483165198235056, "sum": 0.012483165198235056, "min": 0.012483165198235056}}, "EndTime": 1557086563.993442, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.993429}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012479858870482325, "sum": 0.012479858870482325, "min": 0.012479858870482325}}, "EndTime": 1557086563.993491, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.993478}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012482986148278318, "sum": 0.012482986148278318, "min": 0.012482986148278318}}, "EndTime": 1557086563.99354, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086563.993527}
#
# [05/05/2019 20:02:43 INFO 139931280869184] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.0169336282692
# [05/05/2019 20:02:43 INFO 139931280869184] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.00548767899426
# [05/05/2019 20:02:43 INFO 139931280869184] Epoch 1: Loss improved. Updating best model
# [05/05/2019 20:02:43 INFO 139931280869184] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1557086563.997357, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557086557.247574}
#
# [05/05/2019 20:02:43 INFO 139931280869184] #throughput_metric: host=algo-1, train throughput=29535.7579362 records/second
# [2019-05-05 20:02:43.997] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 3, "duration": 6749, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010280890280277885, "sum": 0.010280890280277885, "min": 0.010280890280277885}}, "EndTime": 1557086570.419272, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.419204}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008703173548731971, "sum": 0.008703173548731971, "min": 0.008703173548731971}}, "EndTime": 1557086570.419365, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.419344}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010268610419939511, "sum": 0.010268610419939511, "min": 0.010268610419939511}}, "EndTime": 1557086570.41944, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.41942}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008716777494804344, "sum": 0.008716777494804344, "min": 0.008716777494804344}}, "EndTime": 1557086570.419512, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.419493}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005077203194549934, "sum": 0.005077203194549934, "min": 0.005077203194549934}}, "EndTime": 1557086570.419575, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.419558}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005960388685440897, "sum": 0.005960388685440897, "min": 0.005960388685440897}}, "EndTime": 1557086570.419635, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.419618}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005005124478483919, "sum": 0.005005124478483919, "min": 0.005005124478483919}}, "EndTime": 1557086570.4197, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.419683}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00613126052189712, "sum": 0.00613126052189712, "min": 0.00613126052189712}}, "EndTime": 1557086570.41977, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.419753}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010545964197896832, "sum": 0.010545964197896832, "min": 0.010545964197896832}}, "EndTime": 1557086570.419831, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.419814}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00904736291942884, "sum": 0.00904736291942884, "min": 0.00904736291942884}}, "EndTime": 1557086570.419902, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.419884}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010554662002390953, "sum": 0.010554662002390953, "min": 0.010554662002390953}}, "EndTime": 1557086570.41997, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.419952}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.009047675942655783, "sum": 0.009047675942655783, "min": 0.009047675942655783}}, "EndTime": 1557086570.420038, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420021}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006062194085600388, "sum": 0.006062194085600388, "min": 0.006062194085600388}}, "EndTime": 1557086570.420098, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420082}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005814293683473789, "sum": 0.005814293683473789, "min": 0.005814293683473789}}, "EndTime": 1557086570.420166, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420149}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006061888689671329, "sum": 0.006061888689671329, "min": 0.006061888689671329}}, "EndTime": 1557086570.420234, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420217}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006016780574717114, "sum": 0.006016780574717114, "min": 0.006016780574717114}}, "EndTime": 1557086570.420302, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420284}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015224682985238694, "sum": 0.015224682985238694, "min": 0.015224682985238694}}, "EndTime": 1557086570.420372, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420354}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01397782376064128, "sum": 0.01397782376064128, "min": 0.01397782376064128}}, "EndTime": 1557086570.420431, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420415}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015228877695361574, "sum": 0.015228877695361574, "min": 0.015228877695361574}}, "EndTime": 1557086570.420489, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420473}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013976303852982257, "sum": 0.013976303852982257, "min": 0.013976303852982257}}, "EndTime": 1557086570.420544, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420533}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011517464831246802, "sum": 0.011517464831246802, "min": 0.011517464831246802}}, "EndTime": 1557086570.420602, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420585}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011523272909111712, "sum": 0.011523272909111712, "min": 0.011523272909111712}}, "EndTime": 1557086570.420671, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420654}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011522903874291847, "sum": 0.011522903874291847, "min": 0.011522903874291847}}, "EndTime": 1557086570.420739, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420722}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011532373850669094, "sum": 0.011532373850669094, "min": 0.011532373850669094}}, "EndTime": 1557086570.420804, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420787}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016013618215244618, "sum": 0.016013618215244618, "min": 0.016013618215244618}}, "EndTime": 1557086570.420873, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420855}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01478147773646829, "sum": 0.01478147773646829, "min": 0.01478147773646829}}, "EndTime": 1557086570.420933, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420917}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016018314795278425, "sum": 0.016018314795278425, "min": 0.016018314795278425}}, "EndTime": 1557086570.420992, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.420975}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014780291039740021, "sum": 0.014780291039740021, "min": 0.014780291039740021}}, "EndTime": 1557086570.42106, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.421043}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012480147539071701, "sum": 0.012480147539071701, "min": 0.012480147539071701}}, "EndTime": 1557086570.42112, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.421104}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012490562180178848, "sum": 0.012490562180178848, "min": 0.012490562180178848}}, "EndTime": 1557086570.421177, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.421161}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012479020789040993, "sum": 0.012479020789040993, "min": 0.012479020789040993}}, "EndTime": 1557086570.421245, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.421227}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012491502482088367, "sum": 0.012491502482088367, "min": 0.012491502482088367}}, "EndTime": 1557086570.421314, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086570.421296}
#
# [05/05/2019 20:02:50 INFO 139931280869184] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.0102808902803
# [05/05/2019 20:02:50 INFO 139931280869184] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.00500512447848
# [05/05/2019 20:02:50 INFO 139931280869184] Epoch 2: Loss improved. Updating best model
# [05/05/2019 20:02:50 INFO 139931280869184] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1557086570.42431, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557086563.997649}
#
# [05/05/2019 20:02:50 INFO 139931280869184] #throughput_metric: host=algo-1, train throughput=31020.5806511 records/second
# [2019-05-05 20:02:50.424] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 4, "duration": 6424, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.007993003969815508, "sum": 0.007993003969815508, "min": 0.007993003969815508}}, "EndTime": 1557086576.82057, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557086576.820504}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006652505127029802, "sum": 0.006652505127029802, "min": 0.006652505127029802}}, "EndTime": 1557086576.820661, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557086576.820642}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.007985756025841487, "sum": 0.007985756025841487, "min": 0.007985756025841487}}, "EndTime": 1557086576.820722, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557086576.820706}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0066610379518576, "sum": 0.0066610379518576, "min": 0.0066610379518576}}, "EndTime": 1557086576.820782, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557086576.820766}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004913139717063712, "sum": 0.004913139717063712, "min": 0.004913139717063712}}, "EndTime": 1557086576.820834, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557086576.82082}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006007583376525635, "sum": 0.006007583376525635, "min": 0.006007583376525635}}, "EndTime": 1557086576.820891, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557086576.820875}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004541260230481325, "sum": 0.004541260230481325, "min": 0.004541260230481325}}, "EndTime": 1557086730.909969, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.909955}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004056161796178051, "sum": 0.004056161796178051, "min": 0.004056161796178051}}, "EndTime": 1557086730.910024, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910008}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00397384125009254, "sum": 0.00397384125009254, "min": 0.00397384125009254}}, "EndTime": 1557086730.910076, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910062}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005190758120848905, "sum": 0.005190758120848905, "min": 0.005190758120848905}}, "EndTime": 1557086730.910122, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.91011}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.003973343082408809, "sum": 0.003973343082408809, "min": 0.003973343082408809}}, "EndTime": 1557086730.910177, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.91016}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005208741483826134, "sum": 0.005208741483826134, "min": 0.005208741483826134}}, "EndTime": 1557086730.910232, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910217}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0053864457403595125, "sum": 0.0053864457403595125, "min": 0.0053864457403595125}}, "EndTime": 1557086730.910288, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910273}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005139727617328491, "sum": 0.005139727617328491, "min": 0.005139727617328491}}, "EndTime": 1557086730.910347, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910332}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00533573668027044, "sum": 0.00533573668027044, "min": 0.00533573668027044}}, "EndTime": 1557086730.910403, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910387}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005139719408960198, "sum": 0.005139719408960198, "min": 0.005139719408960198}}, "EndTime": 1557086730.910459, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910444}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005093681085049807, "sum": 0.005093681085049807, "min": 0.005093681085049807}}, "EndTime": 1557086730.910513, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910499}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006105666607768092, "sum": 0.006105666607768092, "min": 0.006105666607768092}}, "EndTime": 1557086730.910569, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910553}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005093690500487035, "sum": 0.005093690500487035, "min": 0.005093690500487035}}, "EndTime": 1557086730.910629, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910613}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006105792368925995, "sum": 0.006105792368925995, "min": 0.006105792368925995}}, "EndTime": 1557086730.910689, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910672}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011675228393257563, "sum": 0.011675228393257563, "min": 0.011675228393257563}}, "EndTime": 1557086730.91075, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910734}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011661708266890827, "sum": 0.011661708266890827, "min": 0.011661708266890827}}, "EndTime": 1557086730.910809, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910793}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0116671499391297, "sum": 0.0116671499391297, "min": 0.0116671499391297}}, "EndTime": 1557086730.910866, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910851}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011661707406067968, "sum": 0.011661707406067968, "min": 0.011661707406067968}}, "EndTime": 1557086730.910926, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.91091}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011660580781836006, "sum": 0.011660580781836006, "min": 0.011660580781836006}}, "EndTime": 1557086730.910966, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910957}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01165691210426877, "sum": 0.01165691210426877, "min": 0.01165691210426877}}, "EndTime": 1557086730.911, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.910989}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011660579335749448, "sum": 0.011660579335749448, "min": 0.011660579335749448}}, "EndTime": 1557086730.911033, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.911023}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011656674038824723, "sum": 0.011656674038824723, "min": 0.011656674038824723}}, "EndTime": 1557086730.911084, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.911073}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012488596610687486, "sum": 0.012488596610687486, "min": 0.012488596610687486}}, "EndTime": 1557086730.911115, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.911108}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012462469092565565, "sum": 0.012462469092565565, "min": 0.012462469092565565}}, "EndTime": 1557086730.911143, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.911136}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01247654838897475, "sum": 0.01247654838897475, "min": 0.01247654838897475}}, "EndTime": 1557086730.91117, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.911163}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012463161851892519, "sum": 0.012463161851892519, "min": 0.012463161851892519}}, "EndTime": 1557086730.9112, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.911193}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012459224031199163, "sum": 0.012459224031199163, "min": 0.012459224031199163}}, "EndTime": 1557086730.911251, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.911237}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012602293426067985, "sum": 0.012602293426067985, "min": 0.012602293426067985}}, "EndTime": 1557086730.911285, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.911275}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012459361534621847, "sum": 0.012459361534621847, "min": 0.012459361534621847}}, "EndTime": 1557086730.911333, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.911318}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012603153902981149, "sum": 0.012603153902981149, "min": 0.012603153902981149}}, "EndTime": 1557086730.9114, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086730.911383}
#
# [05/05/2019 20:05:30 INFO 139931280869184] #quality_metric: host=algo-1, epoch=27, train binary_classification_cross_entropy_objective <loss>=0.00461571828924
# [05/05/2019 20:05:30 INFO 139931280869184] #early_stopping_criteria_metric: host=algo-1, epoch=27, criteria=binary_classification_cross_entropy_objective, value=0.00397334308241
# [05/05/2019 20:05:30 INFO 139931280869184] Early stop condition met. Stopping training.
# [05/05/2019 20:05:30 INFO 139931280869184] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 5612, "sum": 5612.0, "min": 5612}, "Total Records Seen": {"count": 1, "max": 5594192, "sum": 5594192.0, "min": 5594192}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 30, "sum": 30.0, "min": 30}}, "EndTime": 1557086730.913747, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 27}, "StartTime": 1557086724.460953}
#
# [05/05/2019 20:05:30 INFO 139931280869184] #throughput_metric: host=algo-1, train throughput=30895.0649465 records/second
# [05/05/2019 20:05:30 WARNING 139931280869184] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [05/05/2019 20:05:30 WARNING 139931280869184] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-05-05 20:05:30.914] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 29, "duration": 6453, "num_examples": 200}
# [2019-05-05 20:05:30.920] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 30, "duration": 6, "num_examples": 1}
# [2019-05-05 20:05:31.768] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 31, "duration": 845, "num_examples": 200}
# [05/05/2019 20:05:32 INFO 139931280869184] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.0039684858283528081)
# [05/05/2019 20:05:32 INFO 139931280869184] #train_score (algo-1) : ('binary_classification_accuracy', 0.97076202323388372)
# [05/05/2019 20:05:32 INFO 139931280869184] #train_score (algo-1) : ('binary_f_1.000', 0.09473520733033079)
# [05/05/2019 20:05:32 INFO 139931280869184] #train_score (algo-1) : ('precision', 0.049983611930514586)
# [05/05/2019 20:05:32 INFO 139931280869184] #train_score (algo-1) : ('recall', 0.9050445103857567)
# [05/05/2019 20:05:32 INFO 139931280869184] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.00396848582835
# [05/05/2019 20:05:32 INFO 139931280869184] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.970762023234
# [05/05/2019 20:05:32 INFO 139931280869184] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.0947352073303
# [05/05/2019 20:05:32 INFO 139931280869184] #quality_metric: host=algo-1, train precision <score>=0.0499836119305
# [05/05/2019 20:05:32 INFO 139931280869184] #quality_metric: host=algo-1, train recall <score>=0.905044510386
# [05/05/2019 20:05:32 INFO 139931280869184] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [05/05/2019 20:05:32 INFO 139931280869184] Saved checkpoint to "/tmp/tmpfuxLkF/mx-mod-0000.params"
# [05/05/2019 20:05:32 INFO 139931280869184] Test data is not provided.
# [2019-05-05 20:05:32.524] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 32, "duration": 755, "num_examples": 200}
# [2019-05-05 20:05:32.524] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "duration": 181925, "num_epochs": 33, "num_examples": 6013}
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 182166.49103164673, "sum": 182166.49103164673, "min": 182166.49103164673}, "finalize.time": {"count": 1, "max": 1600.9769439697266, "sum": 1600.9769439697266, "min": 1600.9769439697266}, "initialize.time": {"count": 1, "max": 225.10409355163574, "sum": 225.10409355163574, "min": 225.10409355163574}, "check_early_stopping.time": {"count": 28, "max": 1.024007797241211, "sum": 19.58179473876953, "min": 0.1819133758544922}, "setuptime": {"count": 1, "max": 21.62313461303711, "sum": 21.62313461303711, "min": 21.62313461303711}, "update.time": {"count": 28, "max": 6881.708860397339, "sum": 180215.90971946716, "min": 6105.185031890869}, "epochs": {"count": 1, "max": 40, "sum": 40.0, "min": 40}}, "EndTime": 1557086732.524435, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1557086550.451289}
# INFO:sagemaker:Creating model with name: linear-learner-2019-05-05-20-05-55-493
# Billable seconds: 228
# INFO:sagemaker:Creating endpoint with name linear-learner-2019-05-05-19-59-41-755
# ---------------------------------------------------------------------------------------!

# %% [markdown]
# ### Improving recall with class weights
#
# Now we'll improve on these results using a new feature added to linear learner: class weights for binary classification.  We introduced this feature in the *Class Weights* section, and now we'll look into its application to the credit card fraud dataset by training a new model with balanced class weights:

# %%
# Training a binary classifier with class weights and automated threshold tuning
class_weights_hyperparams = {
    'feature_dim': 30,
    'predictor_type': 'binary_classifier',
    'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 
    'target_recall': 0.9,
    'positive_example_weight_mult': 'balanced',
    'epochs': 40
}
class_weights_output_path = 's3://{}/{}/class_weights/output'.format(bucket, prefix)
class_weights_predictor = predictor_from_hyperparams(s3_train_path, class_weights_hyperparams, class_weights_output_path)
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2019-05-05-20-13-15-788
# 2019-05-05 20:13:15 Starting - Starting the training job...
# 2019-05-05 20:13:18 Starting - Launching requested ML instances......
# 2019-05-05 20:14:22 Starting - Preparing the instances for training......
# 2019-05-05 20:15:37 Downloading - Downloading input data...
# 2019-05-05 20:16:13 Training - Downloading the training image.
# Docker entrypoint called with argument(s): train
# [05/05/2019 20:16:20 INFO 140158608070464] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [05/05/2019 20:16:20 INFO 140158608070464] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'40', u'positive_example_weight_mult': u'balanced', u'target_recall': u'0.9'}
# [05/05/2019 20:16:20 INFO 140158608070464] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'40', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'balanced', u'l1': u'auto', u'margin': u'1.0'}
# [05/05/2019 20:16:20 WARNING 140158608070464] Loggers have already been setup.
# Process 1 is a worker.
# [05/05/2019 20:16:20 INFO 140158608070464] Using default worker.
# [2019-05-05 20:16:20.218] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/train", "num_examples": 1000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [30], "storage_type": "dense"}]}
# [2019-05-05 20:16:20.248] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 0, "duration": 30, "num_examples": 1}
# [05/05/2019 20:16:20 INFO 140158608070464] Create Store: local
# [2019-05-05 20:16:20.309] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 1, "duration": 60, "num_examples": 11}
# [05/05/2019 20:16:20 INFO 140158608070464] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f78dbdb6ad0>
# [05/05/2019 20:16:20 INFO 140158608070464] Scaling model computed with parameters:
#  {'stdev_weight':
# [  4.71942188e+04   2.01291966e+00   1.69568098e+00   1.57379591e+00
#    1.42111158e+00   1.74640667e+00   1.51144338e+00   1.63385201e+00
#    1.13653934e+00   1.08314764e+00   1.06824124e+00   1.03516150e+00
#    1.01673567e+00   9.92477775e-01   9.78726447e-01   9.13698077e-01
#    8.90511751e-01   8.58795881e-01   8.44277263e-01   8.11051309e-01
#    9.23640847e-01   7.29950190e-01   7.28531599e-01   6.56139612e-01
#    6.05293095e-01   5.20700455e-01   4.88954067e-01   5.05282402e-01
#    3.77208292e-01   3.40401947e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [  9.41158750e+04  -2.09659096e-02   6.00883830e-03  -6.06044414e-05
#    1.07088813e-03   2.56213127e-03   1.28126498e-02   5.70237590e-03
#    1.37717789e-02   5.02825656e-04  -1.49376029e-02   8.31487868e-03
#    2.41851507e-04  -7.11433776e-03  -6.22152584e-03   1.35600369e-03
#   -3.61267186e-04   4.83268918e-03  -3.69541849e-05   1.13776792e-03
#   -9.44486167e-03  -6.55637588e-03  -1.03078522e-02  -2.02503870e-03
#    3.76771495e-04  -1.49243438e-04   7.94459879e-03   1.23333558e-02
#    2.39625806e-03   8.90791397e+01]
# <NDArray 30 @cpu(0)>}
# [05/05/2019 20:16:20 INFO 140158608070464] nvidia-smi took: 0.0251941680908 secs to identify 0 gpus
# [05/05/2019 20:16:20 INFO 140158608070464] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1557087380.484318, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1557087380.484277}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4429572533842307, "sum": 0.4429572533842307, "min": 0.4429572533842307}}, "EndTime": 1557087387.047394, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.047322}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3757792942679707, "sum": 0.3757792942679707, "min": 0.3757792942679707}}, "EndTime": 1557087387.047485, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.047471}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39737336259391437, "sum": 0.39737336259391437, "min": 0.39737336259391437}}, "EndTime": 1557087387.047537, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.047522}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.42776896736490067, "sum": 0.42776896736490067, "min": 0.42776896736490067}}, "EndTime": 1557087387.047592, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.047577}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4050246883373165, "sum": 0.4050246883373165, "min": 0.4050246883373165}}, "EndTime": 1557087387.047643, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.04763}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.43049607193529904, "sum": 0.43049607193529904, "min": 0.43049607193529904}}, "EndTime": 1557087387.047699, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.047684}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.41021742350132623, "sum": 0.41021742350132623, "min": 0.41021742350132623}}, "EndTime": 1557087387.047756, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.047741}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.42617594456313246, "sum": 0.42617594456313246, "min": 0.42617594456313246}}, "EndTime": 1557087387.047814, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.047798}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39021159167265773, "sum": 0.39021159167265773, "min": 0.39021159167265773}}, "EndTime": 1557087387.047872, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.047856}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4505384884934929, "sum": 0.4505384884934929, "min": 0.4505384884934929}}, "EndTime": 1557087387.047929, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.047914}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44286348686026566, "sum": 0.44286348686026566, "min": 0.44286348686026566}}, "EndTime": 1557087387.047986, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.047971}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4439351986832355, "sum": 0.4439351986832355, "min": 0.4439351986832355}}, "EndTime": 1557087387.048043, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048028}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3987537076461255, "sum": 0.3987537076461255, "min": 0.3987537076461255}}, "EndTime": 1557087387.0481, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048084}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4064254423937007, "sum": 0.4064254423937007, "min": 0.4064254423937007}}, "EndTime": 1557087387.048156, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.04814}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39410735220405924, "sum": 0.39410735220405924, "min": 0.39410735220405924}}, "EndTime": 1557087387.048216, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.0482}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4064912394231288, "sum": 0.4064912394231288, "min": 0.4064912394231288}}, "EndTime": 1557087387.048275, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048259}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4816090850830078, "sum": 0.4816090850830078, "min": 0.4816090850830078}}, "EndTime": 1557087387.048334, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048319}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.42381264952079734, "sum": 0.42381264952079734, "min": 0.42381264952079734}}, "EndTime": 1557087387.04839, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048374}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4391999149801743, "sum": 0.4391999149801743, "min": 0.4391999149801743}}, "EndTime": 1557087387.048449, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048433}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44350351960455353, "sum": 0.44350351960455353, "min": 0.44350351960455353}}, "EndTime": 1557087387.048506, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048491}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4124328654303623, "sum": 0.4124328654303623, "min": 0.4124328654303623}}, "EndTime": 1557087387.048565, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048549}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.41160130979068316, "sum": 0.41160130979068316, "min": 0.41160130979068316}}, "EndTime": 1557087387.048629, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048613}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.411738809135092, "sum": 0.411738809135092, "min": 0.411738809135092}}, "EndTime": 1557087387.048687, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048672}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.41248465077002444, "sum": 0.41248465077002444, "min": 0.41248465077002444}}, "EndTime": 1557087387.048744, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048728}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8971699307695705, "sum": 0.8971699307695705, "min": 0.8971699307695705}}, "EndTime": 1557087387.048801, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048786}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8970431862069135, "sum": 0.8970431862069135, "min": 0.8970431862069135}}, "EndTime": 1557087387.048857, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048842}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9163539370436166, "sum": 0.9163539370436166, "min": 0.9163539370436166}}, "EndTime": 1557087387.048913, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048898}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9041241315525381, "sum": 0.9041241315525381, "min": 0.9041241315525381}}, "EndTime": 1557087387.04898, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.048964}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9832523194892921, "sum": 0.9832523194892921, "min": 0.9832523194892921}}, "EndTime": 1557087387.04904, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.049024}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9731438786492276, "sum": 0.9731438786492276, "min": 0.9731438786492276}}, "EndTime": 1557087387.049097, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.049081}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9896999150568516, "sum": 0.9896999150568516, "min": 0.9896999150568516}}, "EndTime": 1557087387.049155, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.049139}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9859079526201564, "sum": 0.9859079526201564, "min": 0.9859079526201564}}, "EndTime": 1557087387.049211, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087387.049195}
#
# [05/05/2019 20:16:27 INFO 140158608070464] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.442957253384
# [05/05/2019 20:16:27 INFO 140158608070464] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.375779294268
# [05/05/2019 20:16:27 INFO 140158608070464] Epoch 0: Loss improved. Updating best model
# [05/05/2019 20:16:27 INFO 140158608070464] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1557087387.052593, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557087380.484524}
#
# [05/05/2019 20:16:27 INFO 140158608070464] #throughput_metric: host=algo-1, train throughput=30352.9406494 records/second
# [2019-05-05 20:16:27.052] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 2, "duration": 6568, "num_examples": 200}
#
# 2019-05-05 20:16:17 Training - Training image download completed. Training in progress.#metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29214780295673926, "sum": 0.29214780295673926, "min": 0.29214780295673926}}, "EndTime": 1557087393.894395, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.894299}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.26934474220467575, "sum": 0.26934474220467575, "min": 0.26934474220467575}}, "EndTime": 1557087393.894501, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.894484}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2791920412149861, "sum": 0.2791920412149861, "min": 0.2791920412149861}}, "EndTime": 1557087393.894554, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.894542}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2843267681946107, "sum": 0.2843267681946107, "min": 0.2843267681946107}}, "EndTime": 1557087393.8946, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.894589}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33496496973085643, "sum": 0.33496496973085643, "min": 0.33496496973085643}}, "EndTime": 1557087393.894646, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.894635}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3703220954396617, "sum": 0.3703220954396617, "min": 0.3703220954396617}}, "EndTime": 1557087393.894874, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.894856}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33086908677834365, "sum": 0.33086908677834365, "min": 0.33086908677834365}}, "EndTime": 1557087393.894924, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.894912}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3733032534421988, "sum": 0.3733032534421988, "min": 0.3733032534421988}}, "EndTime": 1557087393.894967, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.894957}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2791007601867369, "sum": 0.2791007601867369, "min": 0.2791007601867369}}, "EndTime": 1557087393.89501, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29322024578305345, "sum": 0.29322024578305345, "min": 0.29322024578305345}}, "EndTime": 1557087393.895056, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895045}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2921369547628278, "sum": 0.2921369547628278, "min": 0.2921369547628278}}, "EndTime": 1557087393.8951, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895089}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2903805984420393, "sum": 0.2903805984420393, "min": 0.2903805984420393}}, "EndTime": 1557087393.895143, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895133}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3328220358805441, "sum": 0.3328220358805441, "min": 0.3328220358805441}}, "EndTime": 1557087393.895188, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895177}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.36972100215701004, "sum": 0.36972100215701004, "min": 0.36972100215701004}}, "EndTime": 1557087393.895232, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895221}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3354747246114453, "sum": 0.3354747246114453, "min": 0.3354747246114453}}, "EndTime": 1557087393.895276, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895265}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3709609294584648, "sum": 0.3709609294584648, "min": 0.3709609294584648}}, "EndTime": 1557087393.89532, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895308}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3744950183504191, "sum": 0.3744950183504191, "min": 0.3744950183504191}}, "EndTime": 1557087393.895362, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895352}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37248061838581337, "sum": 0.37248061838581337, "min": 0.37248061838581337}}, "EndTime": 1557087393.895407, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895396}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.372115179397353, "sum": 0.372115179397353, "min": 0.372115179397353}}, "EndTime": 1557087393.89545, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895439}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.372741982733185, "sum": 0.372741982733185, "min": 0.372741982733185}}, "EndTime": 1557087393.895492, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895482}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3971563307603999, "sum": 0.3971563307603999, "min": 0.3971563307603999}}, "EndTime": 1557087393.895537, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895526}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4129681209775072, "sum": 0.4129681209775072, "min": 0.4129681209775072}}, "EndTime": 1557087393.895623, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895609}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39967683094350537, "sum": 0.39967683094350537, "min": 0.39967683094350537}}, "EndTime": 1557087393.895669, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895658}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.41291957919441874, "sum": 0.41291957919441874, "min": 0.41291957919441874}}, "EndTime": 1557087393.895712, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895701}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8927913813758735, "sum": 0.8927913813758735, "min": 0.8927913813758735}}, "EndTime": 1557087393.895754, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895744}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8948884338685615, "sum": 0.8948884338685615, "min": 0.8948884338685615}}, "EndTime": 1557087393.895797, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895786}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8923228025196784, "sum": 0.8923228025196784, "min": 0.8923228025196784}}, "EndTime": 1557087393.895841, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895833}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8943540753695234, "sum": 0.8943540753695234, "min": 0.8943540753695234}}, "EndTime": 1557087393.89587, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895862}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9718443925560419, "sum": 0.9718443925560419, "min": 0.9718443925560419}}, "EndTime": 1557087393.895914, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895902}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9638324370264408, "sum": 0.9638324370264408, "min": 0.9638324370264408}}, "EndTime": 1557087393.895966, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.895952}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9720205453843926, "sum": 0.9720205453843926, "min": 0.9720205453843926}}, "EndTime": 1557087393.896032, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.896016}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9664162966474217, "sum": 0.9664162966474217, "min": 0.9664162966474217}}, "EndTime": 1557087393.896097, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087393.896081}
#
# [05/05/2019 20:16:33 INFO 140158608070464] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.292147802957
# [05/05/2019 20:16:33 INFO 140158608070464] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.269344742205
# [05/05/2019 20:16:33 INFO 140158608070464] Epoch 1: Loss improved. Updating best model
# [05/05/2019 20:16:33 INFO 140158608070464] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1557087393.899048, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557087387.052911}
#
# [05/05/2019 20:16:33 INFO 140158608070464] #throughput_metric: host=algo-1, train throughput=29120.1020199 records/second
# [2019-05-05 20:16:33.899] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 3, "duration": 6846, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.26645391515990596, "sum": 0.26645391515990596, "min": 0.26645391515990596}}, "EndTime": 1557087400.596518, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.596447}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2523200384168769, "sum": 0.2523200384168769, "min": 0.2523200384168769}}, "EndTime": 1557087400.596611, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.596593}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.25930291997248206, "sum": 0.25930291997248206, "min": 0.25930291997248206}}, "EndTime": 1557087400.59667, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.596654}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.260491979397721, "sum": 0.260491979397721, "min": 0.260491979397721}}, "EndTime": 1557087400.596725, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.596711}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3080191592307546, "sum": 0.3080191592307546, "min": 0.3080191592307546}}, "EndTime": 1557087400.596777, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.596763}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3693254737278924, "sum": 0.3693254737278924, "min": 0.3693254737278924}}, "EndTime": 1557087400.596827, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.596813}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3080750139322712, "sum": 0.3080750139322712, "min": 0.3080750139322712}}, "EndTime": 1557087400.596882, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.596867}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.36948000038568696, "sum": 0.36948000038568696, "min": 0.36948000038568696}}, "EndTime": 1557087400.596935, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.596921}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.26035717470562036, "sum": 0.26035717470562036, "min": 0.26035717470562036}}, "EndTime": 1557087400.596989, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.596974}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2664260779145974, "sum": 0.2664260779145974, "min": 0.2664260779145974}}, "EndTime": 1557087400.597046, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597029}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2678363073147721, "sum": 0.2678363073147721, "min": 0.2678363073147721}}, "EndTime": 1557087400.597102, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597087}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.26467211764541704, "sum": 0.26467211764541704, "min": 0.26467211764541704}}, "EndTime": 1557087400.597157, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597142}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3138557098235317, "sum": 0.3138557098235317, "min": 0.3138557098235317}}, "EndTime": 1557087400.597212, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597197}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37690202914290694, "sum": 0.37690202914290694, "min": 0.37690202914290694}}, "EndTime": 1557087400.597266, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597251}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.31516291210040376, "sum": 0.31516291210040376, "min": 0.31516291210040376}}, "EndTime": 1557087400.597319, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597305}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37748922521504924, "sum": 0.37748922521504924, "min": 0.37748922521504924}}, "EndTime": 1557087400.597374, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597358}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3703979521324886, "sum": 0.3703979521324886, "min": 0.3703979521324886}}, "EndTime": 1557087400.59743, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597415}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.372196796398067, "sum": 0.372196796398067, "min": 0.372196796398067}}, "EndTime": 1557087400.597487, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597471}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3703843094715521, "sum": 0.3703843094715521, "min": 0.3703843094715521}}, "EndTime": 1557087400.597543, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597528}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37210454490316575, "sum": 0.37210454490316575, "min": 0.37210454490316575}}, "EndTime": 1557087400.597597, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597582}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39085777712107905, "sum": 0.39085777712107905, "min": 0.39085777712107905}}, "EndTime": 1557087400.597654, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597638}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4113058956088732, "sum": 0.4113058956088732, "min": 0.4113058956088732}}, "EndTime": 1557087400.597728, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597705}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3919685974121094, "sum": 0.3919685974121094, "min": 0.3919685974121094}}, "EndTime": 1557087400.597786, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597771}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.41094207615109546, "sum": 0.41094207615109546, "min": 0.41094207615109546}}, "EndTime": 1557087400.597846, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597829}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8916502250019629, "sum": 0.8916502250019629, "min": 0.8916502250019629}}, "EndTime": 1557087400.597911, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597895}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8947478547216061, "sum": 0.8947478547216061, "min": 0.8947478547216061}}, "EndTime": 1557087400.597975, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.597959}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8914581262023006, "sum": 0.8914581262023006, "min": 0.8914581262023006}}, "EndTime": 1557087400.598039, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.598023}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.894494341366255, "sum": 0.894494341366255, "min": 0.894494341366255}}, "EndTime": 1557087400.598103, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.598087}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9781919317964334, "sum": 0.9781919317964334, "min": 0.9781919317964334}}, "EndTime": 1557087400.598168, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.598152}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9640563561520984, "sum": 0.9640563561520984, "min": 0.9640563561520984}}, "EndTime": 1557087400.598232, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.598216}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9798433226005516, "sum": 0.9798433226005516, "min": 0.9798433226005516}}, "EndTime": 1557087400.598287, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.598272}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9672219477514525, "sum": 0.9672219477514525, "min": 0.9672219477514525}}, "EndTime": 1557087400.598341, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087400.598329}
#
# [05/05/2019 20:16:40 INFO 140158608070464] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.26645391516
# [05/05/2019 20:16:40 INFO 140158608070464] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.252320038417
# [05/05/2019 20:16:40 INFO 140158608070464] Epoch 2: Loss improved. Updating best model
# [05/05/2019 20:16:40 INFO 140158608070464] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1557087400.601292, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557087393.899358}
#
# [05/05/2019 20:16:40 INFO 140158608070464] #throughput_metric: host=algo-1, train throughput=29746.6971954 records/second
# [2019-05-05 20:16:40.601] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 4, "duration": 6702, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2547896150751929, "sum": 0.2547896150751929, "min": 0.2547896150751929}}, "EndTime": 1557087407.348652, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557087407.348581}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.24431480229440047, "sum": 0.24431480229440047, "min": 0.24431480229440047}}, "EndTime": 1557087407.348743, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557087407.348725}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.24987041197350277, "sum": 0.24987041197350277, "min": 0.24987041197350277}}, "EndTime": 1557087407.348803, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557087407.348788}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2497052208215148, "sum": 0.2497052208215148, "min": 0.2497052208215148}}, "EndTime": 1557087407.34886, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557087407.348845}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.22250657437195132, "sum": 0.22250657437195132, "min": 0.22250657437195132}}, "EndTime": 1557087583.418461, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.418447}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.21418275022267097, "sum": 0.21418275022267097, "min": 0.21418275022267097}}, "EndTime": 1557087583.418514, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.4185}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.30421839766765957, "sum": 0.30421839766765957, "min": 0.30421839766765957}}, "EndTime": 1557087583.418562, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.418549}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.21417349469362193, "sum": 0.21417349469362193, "min": 0.21417349469362193}}, "EndTime": 1557087583.418616, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.418601}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.30438729279484583, "sum": 0.30438729279484583, "min": 0.30438729279484583}}, "EndTime": 1557087583.418674, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.418659}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2317850536940685, "sum": 0.2317850536940685, "min": 0.2317850536940685}}, "EndTime": 1557087583.418732, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.418716}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2297468843316313, "sum": 0.2297468843316313, "min": 0.2297468843316313}}, "EndTime": 1557087583.418794, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.418779}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2330201148795123, "sum": 0.2330201148795123, "min": 0.2330201148795123}}, "EndTime": 1557087583.418882, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.418866}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.22974166293120266, "sum": 0.22974166293120266, "min": 0.22974166293120266}}, "EndTime": 1557087583.418948, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.418932}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.22385930146643865, "sum": 0.22385930146643865, "min": 0.22385930146643865}}, "EndTime": 1557087583.419008, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.418992}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3110906897310037, "sum": 0.3110906897310037, "min": 0.3110906897310037}}, "EndTime": 1557087583.419072, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419056}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2238596821693919, "sum": 0.2238596821693919, "min": 0.2238596821693919}}, "EndTime": 1557087583.419131, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419116}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.31109028960951607, "sum": 0.31109028960951607, "min": 0.31109028960951607}}, "EndTime": 1557087583.419186, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419171}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3640479397414318, "sum": 0.3640479397414318, "min": 0.3640479397414318}}, "EndTime": 1557087583.419243, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419227}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3699407988121761, "sum": 0.3699407988121761, "min": 0.3699407988121761}}, "EndTime": 1557087583.419299, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419283}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3643585246483884, "sum": 0.3643585246483884, "min": 0.3643585246483884}}, "EndTime": 1557087583.419355, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419339}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.36994065998786657, "sum": 0.36994065998786657, "min": 0.36994065998786657}}, "EndTime": 1557087583.419411, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419396}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.36470518524323275, "sum": 0.36470518524323275, "min": 0.36470518524323275}}, "EndTime": 1557087583.419467, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419452}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3867021157729566, "sum": 0.3867021157729566, "min": 0.3867021157729566}}, "EndTime": 1557087583.419523, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419508}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.36470521537742423, "sum": 0.36470521537742423, "min": 0.36470521537742423}}, "EndTime": 1557087583.41958, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419565}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.38670182815628434, "sum": 0.38670182815628434, "min": 0.38670182815628434}}, "EndTime": 1557087583.419637, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419621}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8851739213646357, "sum": 0.8851739213646357, "min": 0.8851739213646357}}, "EndTime": 1557087583.419701, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419686}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.891096771853653, "sum": 0.891096771853653, "min": 0.891096771853653}}, "EndTime": 1557087583.419764, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419748}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8857560987616304, "sum": 0.8857560987616304, "min": 0.8857560987616304}}, "EndTime": 1557087583.419814, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.4198}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8910968637130967, "sum": 0.8910968637130967, "min": 0.8910968637130967}}, "EndTime": 1557087583.419866, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419852}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8865078011517549, "sum": 0.8865078011517549, "min": 0.8865078011517549}}, "EndTime": 1557087583.419921, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419906}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9715061470683496, "sum": 0.9715061470683496, "min": 0.9715061470683496}}, "EndTime": 1557087583.419976, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.419961}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8865077663402462, "sum": 0.8865077663402462, "min": 0.8865077663402462}}, "EndTime": 1557087583.420027, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.420017}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9714938602926743, "sum": 0.9714938602926743, "min": 0.9714938602926743}}, "EndTime": 1557087583.420063, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087583.420051}
#
# [05/05/2019 20:19:43 INFO 140158608070464] #quality_metric: host=algo-1, epoch=30, train binary_classification_weighted_cross_entropy_objective <loss>=0.230289044903
# [05/05/2019 20:19:43 INFO 140158608070464] #early_stopping_criteria_metric: host=algo-1, epoch=30, criteria=binary_classification_weighted_cross_entropy_objective, value=0.214173494694
# [05/05/2019 20:19:43 INFO 140158608070464] Early stop condition met. Stopping training.
# [05/05/2019 20:19:43 INFO 140158608070464] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 6212, "sum": 6212.0, "min": 6212}, "Total Records Seen": {"count": 1, "max": 6192284, "sum": 6192284.0, "min": 6192284}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 33, "sum": 33.0, "min": 33}}, "EndTime": 1557087583.422468, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1557087577.176646}
#
# [05/05/2019 20:19:43 INFO 140158608070464] #throughput_metric: host=algo-1, train throughput=31918.8979599 records/second
# [05/05/2019 20:19:43 WARNING 140158608070464] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [05/05/2019 20:19:43 WARNING 140158608070464] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-05-05 20:19:43.422] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 32, "duration": 6246, "num_examples": 200}
# [2019-05-05 20:19:43.429] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 33, "duration": 6, "num_examples": 1}
# [2019-05-05 20:19:44.183] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 34, "duration": 749, "num_examples": 200}
# [05/05/2019 20:19:44 INFO 140158608070464] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.21347689108625562)
# [05/05/2019 20:19:44 INFO 140158608070464] #train_score (algo-1) : ('binary_classification_accuracy', 0.98864388756244859)
# [05/05/2019 20:19:44 INFO 140158608070464] #train_score (algo-1) : ('binary_f_1.000', 0.2116991643454039)
# [05/05/2019 20:19:44 INFO 140158608070464] #train_score (algo-1) : ('precision', 0.11992110453648915)
# [05/05/2019 20:19:44 INFO 140158608070464] #train_score (algo-1) : ('recall', 0.9020771513353115)
# [05/05/2019 20:19:44 INFO 140158608070464] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.213476891086
# [05/05/2019 20:19:44 INFO 140158608070464] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.988643887562
# [05/05/2019 20:19:44 INFO 140158608070464] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.211699164345
# [05/05/2019 20:19:44 INFO 140158608070464] #quality_metric: host=algo-1, train precision <score>=0.119921104536
# [05/05/2019 20:19:44 INFO 140158608070464] #quality_metric: host=algo-1, train recall <score>=0.902077151335
# [05/05/2019 20:19:44 INFO 140158608070464] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [05/05/2019 20:19:44 INFO 140158608070464] Saved checkpoint to "/tmp/tmp9vVkYs/mx-mod-0000.params"
# [05/05/2019 20:19:44 INFO 140158608070464] Test data is not provided.
# [2019-05-05 20:19:44.977] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 35, "duration": 794, "num_examples": 200}
# [2019-05-05 20:19:44.977] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "duration": 204558, "num_epochs": 36, "num_examples": 6613}
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 204852.01001167297, "sum": 204852.01001167297, "min": 204852.01001167297}, "finalize.time": {"count": 1, "max": 1541.4769649505615, "sum": 1541.4769649505615, "min": 1541.4769649505615}, "initialize.time": {"count": 1, "max": 262.7549171447754, "sum": 262.7549171447754, "min": 262.7549171447754}, "check_early_stopping.time": {"count": 31, "max": 1.1758804321289062, "sum": 25.04730224609375, "min": 0.18978118896484375}, "setuptime": {"count": 1, "max": 18.5549259185791, "sum": 18.5549259185791, "min": 18.5549259185791}, "update.time": {"count": 31, "max": 7057.229995727539, "sum": 202923.31552505493, "min": 6084.0489864349365}, "epochs": {"count": 1, "max": 40, "sum": 40.0, "min": 40}}, "EndTime": 1557087584.977837, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1557087380.216545}
#
# Billable seconds: 252
# INFO:sagemaker:Creating endpoint with name linear-learner-2019-05-05-20-13-15-788
# ----------------------------------------------------------------------------------------!

# %% [markdown]
# The first training examples used the default loss function for binary classification, logistic loss.  Now let's train a model with hinge loss.  This is also called a support vector machine (SVM) classifier with a linear kernel.  Threshold tuning is supported for all binary classifier models in linear learner.

# %%
# Training a binary classifier with hinge loss and automated threshold tuning
svm_hyperparams = {
    'feature_dim': 30,
    'predictor_type': 'binary_classifier',
    'loss': 'hinge_loss',
    'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 
    'target_recall': 0.9,
    'epochs': 40
}
svm_output_path = 's3://{}/{}/svm/output'.format(bucket, prefix)
svm_predictor = predictor_from_hyperparams(s3_train_path, svm_hyperparams, svm_output_path)
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2019-05-05-20-27-25-506
# 2019-05-05 20:27:25 Starting - Starting the training job...
# 2019-05-05 20:27:26 Starting - Launching requested ML instances......
# 2019-05-05 20:28:26 Starting - Preparing the instances for training...
# 2019-05-05 20:29:24 Downloading - Downloading input data
# 2019-05-05 20:29:24 Training - Downloading the training image.....
# Docker entrypoint called with argument(s): train
# [05/05/2019 20:30:10 INFO 139688129685312] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [05/05/2019 20:30:10 INFO 139688129685312] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'loss': u'hinge_loss', u'predictor_type': u'binary_classifier', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'40', u'feature_dim': u'30', u'target_recall': u'0.9'}
# [05/05/2019 20:30:10 INFO 139688129685312] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'40', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'hinge_loss', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [05/05/2019 20:30:10 WARNING 139688129685312] Loggers have already been setup.
# Process 1 is a worker.
# [05/05/2019 20:30:10 INFO 139688129685312] Using default worker.
# [2019-05-05 20:30:10.683] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/train", "num_examples": 1000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [30], "storage_type": "dense"}]}
# [2019-05-05 20:30:10.716] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 0, "duration": 33, "num_examples": 1}
# [05/05/2019 20:30:10 INFO 139688129685312] Create Store: local
# [2019-05-05 20:30:10.876] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 1, "duration": 158, "num_examples": 11}
# [05/05/2019 20:30:10 INFO 139688129685312] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f0b5d2a1ad0>
# [05/05/2019 20:30:10 INFO 139688129685312] Scaling model computed with parameters:
#  {'stdev_weight':
# [  4.71942188e+04   2.01291966e+00   1.69568098e+00   1.57379591e+00
#    1.42111158e+00   1.74640667e+00   1.51144338e+00   1.63385201e+00
#    1.13653934e+00   1.08314764e+00   1.06824124e+00   1.03516150e+00
#    1.01673567e+00   9.92477775e-01   9.78726447e-01   9.13698077e-01
#    8.90511751e-01   8.58795881e-01   8.44277263e-01   8.11051309e-01
#    9.23640847e-01   7.29950190e-01   7.28531599e-01   6.56139612e-01
#    6.05293095e-01   5.20700455e-01   4.88954067e-01   5.05282402e-01
#    3.77208292e-01   3.40401947e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [  9.41158750e+04  -2.09659096e-02   6.00883830e-03  -6.06044414e-05
#    1.07088813e-03   2.56213127e-03   1.28126498e-02   5.70237590e-03
#    1.37717789e-02   5.02825656e-04  -1.49376029e-02   8.31487868e-03
#    2.41851507e-04  -7.11433776e-03  -6.22152584e-03   1.35600369e-03
#   -3.61267186e-04   4.83268918e-03  -3.69541849e-05   1.13776792e-03
#   -9.44486167e-03  -6.55637588e-03  -1.03078522e-02  -2.02503870e-03
#    3.76771495e-04  -1.49243438e-04   7.94459879e-03   1.23333558e-02
#    2.39625806e-03   8.90791397e+01]
# <NDArray 30 @cpu(0)>}
# [05/05/2019 20:30:10 INFO 139688129685312] nvidia-smi took: 0.0251748561859 secs to identify 0 gpus
# [05/05/2019 20:30:10 INFO 139688129685312] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1557088211.041109, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1557088211.041071}
#
#
# 2019-05-05 20:30:07 Training - Training image download completed. Training in progress.#metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0018116748072394176, "sum": 0.0018116748072394176, "min": 0.0018116748072394176}}, "EndTime": 1557088217.646485, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.646417}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.002015070597280809, "sum": 0.002015070597280809, "min": 0.002015070597280809}}, "EndTime": 1557088217.646583, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.646564}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0019441978922441377, "sum": 0.0019441978922441377, "min": 0.0019441978922441377}}, "EndTime": 1557088217.646643, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.646627}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0025210172285386667, "sum": 0.0025210172285386667, "min": 0.0025210172285386667}}, "EndTime": 1557088217.646698, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.646683}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.005967494077418917, "sum": 0.005967494077418917, "min": 0.005967494077418917}}, "EndTime": 1557088217.646747, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.646734}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0057897313431878785, "sum": 0.0057897313431878785, "min": 0.0057897313431878785}}, "EndTime": 1557088217.646797, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.646782}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.005555503348010269, "sum": 0.005555503348010269, "min": 0.005555503348010269}}, "EndTime": 1557088217.646853, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.646837}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.005891700231250207, "sum": 0.005891700231250207, "min": 0.005891700231250207}}, "EndTime": 1557088217.64691, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.646894}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0018938621889107192, "sum": 0.0018938621889107192, "min": 0.0018938621889107192}}, "EndTime": 1557088217.646967, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.646952}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.002059078201127412, "sum": 0.002059078201127412, "min": 0.002059078201127412}}, "EndTime": 1557088217.647019, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647005}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.002165887099863896, "sum": 0.002165887099863896, "min": 0.002165887099863896}}, "EndTime": 1557088217.647075, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.64706}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0020032939434650554, "sum": 0.0020032939434650554, "min": 0.0020032939434650554}}, "EndTime": 1557088217.64713, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647114}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.004884228542222449, "sum": 0.004884228542222449, "min": 0.004884228542222449}}, "EndTime": 1557088217.64718, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.64717}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.005251828231404175, "sum": 0.005251828231404175, "min": 0.005251828231404175}}, "EndTime": 1557088217.647209, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647202}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.005210556225561018, "sum": 0.005210556225561018, "min": 0.005210556225561018}}, "EndTime": 1557088217.647236, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647229}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0048473272844774635, "sum": 0.0048473272844774635, "min": 0.0048473272844774635}}, "EndTime": 1557088217.647263, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647256}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0025154312053817, "sum": 0.0025154312053817, "min": 0.0025154312053817}}, "EndTime": 1557088217.647321, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647305}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0022845629858012175, "sum": 0.0022845629858012175, "min": 0.0022845629858012175}}, "EndTime": 1557088217.64738, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647365}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.002832320165544299, "sum": 0.002832320165544299, "min": 0.002832320165544299}}, "EndTime": 1557088217.647438, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647423}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0026686776112671475, "sum": 0.0026686776112671475, "min": 0.0026686776112671475}}, "EndTime": 1557088217.647495, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647479}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.006785378970992026, "sum": 0.006785378970992026, "min": 0.006785378970992026}}, "EndTime": 1557088217.647552, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647537}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.006963614492260631, "sum": 0.006963614492260631, "min": 0.006963614492260631}}, "EndTime": 1557088217.647636, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.64762}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.007009109179278714, "sum": 0.007009109179278714, "min": 0.007009109179278714}}, "EndTime": 1557088217.647695, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.64768}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.006562111826622905, "sum": 0.006562111826622905, "min": 0.006562111826622905}}, "EndTime": 1557088217.647753, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647738}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.003115575892242355, "sum": 0.003115575892242355, "min": 0.003115575892242355}}, "EndTime": 1557088217.647809, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647794}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0032481219519921883, "sum": 0.0032481219519921883, "min": 0.0032481219519921883}}, "EndTime": 1557088217.647865, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647851}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0032627059553735818, "sum": 0.0032627059553735818, "min": 0.0032627059553735818}}, "EndTime": 1557088217.647922, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647908}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0032575986196647336, "sum": 0.0032575986196647336, "min": 0.0032575986196647336}}, "EndTime": 1557088217.64798, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.647965}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.007576047685877163, "sum": 0.007576047685877163, "min": 0.007576047685877163}}, "EndTime": 1557088217.648035, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.648021}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.007986790407243087, "sum": 0.007986790407243087, "min": 0.007986790407243087}}, "EndTime": 1557088217.64809, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.648075}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.007956158778775278, "sum": 0.007956158778775278, "min": 0.007956158778775278}}, "EndTime": 1557088217.648158, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.648141}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.007916412951359197, "sum": 0.007916412951359197, "min": 0.007916412951359197}}, "EndTime": 1557088217.648214, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088217.648199}
#
# [05/05/2019 20:30:17 INFO 139688129685312] #quality_metric: host=algo-1, epoch=0, train binary_classification_hinge_loss_objective <loss>=0.00181167480724
# [05/05/2019 20:30:17 INFO 139688129685312] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_hinge_loss_objective, value=0.00181167480724
# [05/05/2019 20:30:17 INFO 139688129685312] Epoch 0: Loss improved. Updating best model
# [05/05/2019 20:30:17 INFO 139688129685312] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1557088217.651704, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557088211.041332}
#
# [05/05/2019 20:30:17 INFO 139688129685312] #throughput_metric: host=algo-1, train throughput=30158.704985 records/second
# [2019-05-05 20:30:17.651] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 2, "duration": 6610, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009650865421822323, "sum": 0.0009650865421822323, "min": 0.0009650865421822323}}, "EndTime": 1557088225.020069, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.019999}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0010022569039658685, "sum": 0.0010022569039658685, "min": 0.0010022569039658685}}, "EndTime": 1557088225.020152, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020138}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009986733580054949, "sum": 0.0009986733580054949, "min": 0.0009986733580054949}}, "EndTime": 1557088225.020207, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020193}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0010063857036319809, "sum": 0.0010063857036319809, "min": 0.0010063857036319809}}, "EndTime": 1557088225.020256, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020244}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.004256593356779473, "sum": 0.004256593356779473, "min": 0.004256593356779473}}, "EndTime": 1557088225.020289, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020281}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.005333349916803178, "sum": 0.005333349916803178, "min": 0.005333349916803178}}, "EndTime": 1557088225.020317, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.02031}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.004380926978048967, "sum": 0.004380926978048967, "min": 0.004380926978048967}}, "EndTime": 1557088225.020368, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020354}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.004915374542600545, "sum": 0.004915374542600545, "min": 0.004915374542600545}}, "EndTime": 1557088225.020418, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020405}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009848924722503777, "sum": 0.0009848924722503777, "min": 0.0009848924722503777}}, "EndTime": 1557088225.020467, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020454}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0010059975625282555, "sum": 0.0010059975625282555, "min": 0.0010059975625282555}}, "EndTime": 1557088225.020521, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020507}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0010189456295727486, "sum": 0.0010189456295727486, "min": 0.0010189456295727486}}, "EndTime": 1557088225.020576, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020561}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0010142156715369104, "sum": 0.0010142156715369104, "min": 0.0010142156715369104}}, "EndTime": 1557088225.020634, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020619}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0038151146868365495, "sum": 0.0038151146868365495, "min": 0.0038151146868365495}}, "EndTime": 1557088225.020691, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020676}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0037821329604441197, "sum": 0.0037821329604441197, "min": 0.0037821329604441197}}, "EndTime": 1557088225.020748, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020732}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.003211983974255509, "sum": 0.003211983974255509, "min": 0.003211983974255509}}, "EndTime": 1557088225.020803, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020789}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0035431898766426586, "sum": 0.0035431898766426586, "min": 0.0035431898766426586}}, "EndTime": 1557088225.02086, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020845}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0015143207288417385, "sum": 0.0015143207288417385, "min": 0.0015143207288417385}}, "EndTime": 1557088225.020916, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020901}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0014528452150860624, "sum": 0.0014528452150860624, "min": 0.0014528452150860624}}, "EndTime": 1557088225.020972, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.020956}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.001562050629650528, "sum": 0.001562050629650528, "min": 0.001562050629650528}}, "EndTime": 1557088225.021029, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021014}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0015291098818445027, "sum": 0.0015291098818445027, "min": 0.0015291098818445027}}, "EndTime": 1557088225.021085, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.02107}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0018665013958012039, "sum": 0.0018665013958012039, "min": 0.0018665013958012039}}, "EndTime": 1557088225.021143, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021127}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0019946094748362823, "sum": 0.0019946094748362823, "min": 0.0019946094748362823}}, "EndTime": 1557088225.0212, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021184}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0017977078608681807, "sum": 0.0017977078608681807, "min": 0.0017977078608681807}}, "EndTime": 1557088225.021257, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021242}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.002017016917017836, "sum": 0.002017016917017836, "min": 0.002017016917017836}}, "EndTime": 1557088225.021314, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021299}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.001961382638868974, "sum": 0.001961382638868974, "min": 0.001961382638868974}}, "EndTime": 1557088225.02137, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021355}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.00207251792277523, "sum": 0.00207251792277523, "min": 0.00207251792277523}}, "EndTime": 1557088225.021426, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021411}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0020034936546680314, "sum": 0.0020034936546680314, "min": 0.0020034936546680314}}, "EndTime": 1557088225.021484, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021469}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0020668353974519662, "sum": 0.0020668353974519662, "min": 0.0020668353974519662}}, "EndTime": 1557088225.021543, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021527}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.015127158977278513, "sum": 0.015127158977278513, "min": 0.015127158977278513}}, "EndTime": 1557088225.021603, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021588}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.017551734212654917, "sum": 0.017551734212654917, "min": 0.017551734212654917}}, "EndTime": 1557088225.021661, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021645}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.014359936562015783, "sum": 0.014359936562015783, "min": 0.014359936562015783}}, "EndTime": 1557088225.021728, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021712}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.011567659051574055, "sum": 0.011567659051574055, "min": 0.011567659051574055}}, "EndTime": 1557088225.021793, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088225.021777}
#
# [05/05/2019 20:30:25 INFO 139688129685312] #quality_metric: host=algo-1, epoch=1, train binary_classification_hinge_loss_objective <loss>=0.000965086542182
# [05/05/2019 20:30:25 INFO 139688129685312] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_hinge_loss_objective, value=0.000965086542182
# [05/05/2019 20:30:25 INFO 139688129685312] Epoch 1: Loss improved. Updating best model
# [05/05/2019 20:30:25 INFO 139688129685312] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1557088225.02481, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557088217.65203}
#
# [05/05/2019 20:30:25 INFO 139688129685312] #throughput_metric: host=algo-1, train throughput=27040.0039974 records/second
# [2019-05-05 20:30:25.025] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 3, "duration": 7372, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009311924317673822, "sum": 0.0009311924317673822, "min": 0.0009311924317673822}}, "EndTime": 1557088231.604709, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.604645}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009674621085126197, "sum": 0.0009674621085126197, "min": 0.0009674621085126197}}, "EndTime": 1557088231.604877, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.604851}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009545673885237631, "sum": 0.0009545673885237631, "min": 0.0009545673885237631}}, "EndTime": 1557088231.604941, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.604924}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009825643404344818, "sum": 0.0009825643404344818, "min": 0.0009825643404344818}}, "EndTime": 1557088231.605006, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.604989}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.003536186817303375, "sum": 0.003536186817303375, "min": 0.003536186817303375}}, "EndTime": 1557088231.605076, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605059}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.005311668034174933, "sum": 0.005311668034174933, "min": 0.005311668034174933}}, "EndTime": 1557088231.605143, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605127}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.004111128017530968, "sum": 0.004111128017530968, "min": 0.004111128017530968}}, "EndTime": 1557088231.605212, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605195}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0049360741790215575, "sum": 0.0049360741790215575, "min": 0.0049360741790215575}}, "EndTime": 1557088231.605269, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605254}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009480177974281599, "sum": 0.0009480177974281599, "min": 0.0009480177974281599}}, "EndTime": 1557088231.605327, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605312}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0010070105115672452, "sum": 0.0010070105115672452, "min": 0.0010070105115672452}}, "EndTime": 1557088231.605386, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.60537}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009696109510546353, "sum": 0.0009696109510546353, "min": 0.0009696109510546353}}, "EndTime": 1557088231.605448, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605433}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.00097306563371989, "sum": 0.00097306563371989, "min": 0.00097306563371989}}, "EndTime": 1557088231.605516, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.6055}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0024649780138054087, "sum": 0.0024649780138054087, "min": 0.0024649780138054087}}, "EndTime": 1557088231.605575, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605559}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.003367465691350812, "sum": 0.003367465691350812, "min": 0.003367465691350812}}, "EndTime": 1557088231.605641, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605625}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.002892423392839767, "sum": 0.002892423392839767, "min": 0.002892423392839767}}, "EndTime": 1557088231.605707, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605691}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.002647722307162069, "sum": 0.002647722307162069, "min": 0.002647722307162069}}, "EndTime": 1557088231.605765, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605749}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0013224645024399512, "sum": 0.0013224645024399512, "min": 0.0013224645024399512}}, "EndTime": 1557088231.605821, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605806}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0013467460569817967, "sum": 0.0013467460569817967, "min": 0.0013467460569817967}}, "EndTime": 1557088231.605879, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605863}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.001337612639944158, "sum": 0.001337612639944158, "min": 0.001337612639944158}}, "EndTime": 1557088231.605937, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605921}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0013438640756429589, "sum": 0.0013438640756429589, "min": 0.0013438640756429589}}, "EndTime": 1557088231.605994, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.605979}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0018923604459543924, "sum": 0.0018923604459543924, "min": 0.0018923604459543924}}, "EndTime": 1557088231.606059, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.606044}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.003012658132530337, "sum": 0.003012658132530337, "min": 0.003012658132530337}}, "EndTime": 1557088231.606125, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.606109}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0017241435395413307, "sum": 0.0017241435395413307, "min": 0.0017241435395413307}}, "EndTime": 1557088231.606181, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.606167}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.001990680849731867, "sum": 0.001990680849731867, "min": 0.001990680849731867}}, "EndTime": 1557088231.606232, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.606218}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.002079914678281276, "sum": 0.002079914678281276, "min": 0.002079914678281276}}, "EndTime": 1557088231.606286, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.606271}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0025745190483840866, "sum": 0.0025745190483840866, "min": 0.0025745190483840866}}, "EndTime": 1557088231.606341, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.606326}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.001898759295255994, "sum": 0.001898759295255994, "min": 0.001898759295255994}}, "EndTime": 1557088231.606396, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.606382}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0026202576561788816, "sum": 0.0026202576561788816, "min": 0.0026202576561788816}}, "EndTime": 1557088231.606437, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.606422}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.008994373708514114, "sum": 0.008994373708514114, "min": 0.008994373708514114}}, "EndTime": 1557088231.606492, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.606477}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.008042136352265899, "sum": 0.008042136352265899, "min": 0.008042136352265899}}, "EndTime": 1557088231.606548, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.606533}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.009502936662741043, "sum": 0.009502936662741043, "min": 0.009502936662741043}}, "EndTime": 1557088231.606602, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.606589}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.019489299630399925, "sum": 0.019489299630399925, "min": 0.019489299630399925}}, "EndTime": 1557088231.606644, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088231.60663}
#
# [05/05/2019 20:30:31 INFO 139688129685312] #quality_metric: host=algo-1, epoch=2, train binary_classification_hinge_loss_objective <loss>=0.000931192431767
# [05/05/2019 20:30:31 INFO 139688129685312] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_hinge_loss_objective, value=0.000931192431767
# [05/05/2019 20:30:31 INFO 139688129685312] Epoch 2: Loss improved. Updating best model
# [05/05/2019 20:30:31 INFO 139688129685312] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1557088231.609519, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557088225.025125}
#
# [05/05/2019 20:30:31 INFO 139688129685312] #throughput_metric: host=algo-1, train throughput=30277.6679698 records/second
# [2019-05-05 20:30:31.609] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 4, "duration": 6584, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009210350565874397, "sum": 0.0009210350565874397, "min": 0.0009210350565874397}}, "EndTime": 1557088237.998479, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557088237.998411}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.00096136007611476, "sum": 0.00096136007611476, "min": 0.00096136007611476}}, "EndTime": 1557088237.998568, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557088237.998549}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009429244974150729, "sum": 0.0009429244974150729, "min": 0.0009429244974150729}}, "EndTime": 1557088237.998628, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557088237.998613}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009572887881916372, "sum": 0.0009572887881916372, "min": 0.0009572887881916372}}, "EndTime": 1557088237.998687, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557088237.998672}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0032530614083735787, "sum": 0.0032530614083735787, "min": 0.0032530614083735787}}, "EndTime": 1557088237.998738, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557088237.998724}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.005323463843695482, "sum": 0.005323463843695482, "min": 0.005323463843695482}}, "EndTime": 1557088237.998795, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557088237.998779}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009272280038900711, "sum": 0.0009272280038900711, "min": 0.0009272280038900711}}, "EndTime": 1557088389.667887, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.667874}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0008434216974668167, "sum": 0.0008434216974668167, "min": 0.0008434216974668167}}, "EndTime": 1557088389.667921, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.667913}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.00401537024974823, "sum": 0.00401537024974823, "min": 0.00401537024974823}}, "EndTime": 1557088389.667954, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.667943}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0008385620168854843, "sum": 0.0008385620168854843, "min": 0.0008385620168854843}}, "EndTime": 1557088389.668006, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.667992}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0038854985662441156, "sum": 0.0038854985662441156, "min": 0.0038854985662441156}}, "EndTime": 1557088389.668054, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668044}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.000838588163911847, "sum": 0.000838588163911847, "min": 0.000838588163911847}}, "EndTime": 1557088389.668085, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668077}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.000934536464811869, "sum": 0.000934536464811869, "min": 0.000934536464811869}}, "EndTime": 1557088389.668117, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668106}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0008410245093830567, "sum": 0.0008410245093830567, "min": 0.0008410245093830567}}, "EndTime": 1557088389.668168, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668154}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0009243577727345965, "sum": 0.0009243577727345965, "min": 0.0009243577727345965}}, "EndTime": 1557088389.668222, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668206}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.000855658104783626, "sum": 0.000855658104783626, "min": 0.000855658104783626}}, "EndTime": 1557088389.668273, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668261}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.002012512681622002, "sum": 0.002012512681622002, "min": 0.002012512681622002}}, "EndTime": 1557088389.668329, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668314}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0008555103077660853, "sum": 0.0008555103077660853, "min": 0.0008555103077660853}}, "EndTime": 1557088389.668384, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668369}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0020437191841590346, "sum": 0.0020437191841590346, "min": 0.0020437191841590346}}, "EndTime": 1557088389.668431, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668421}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0011896858270310483, "sum": 0.0011896858270310483, "min": 0.0011896858270310483}}, "EndTime": 1557088389.66846, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668453}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0013703100085866885, "sum": 0.0013703100085866885, "min": 0.0013703100085866885}}, "EndTime": 1557088389.668505, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668493}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.001193971522191034, "sum": 0.001193971522191034, "min": 0.001193971522191034}}, "EndTime": 1557088389.668551, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668537}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.001341322134506313, "sum": 0.001341322134506313, "min": 0.001341322134506313}}, "EndTime": 1557088389.668608, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668592}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.001227208376590668, "sum": 0.001227208376590668, "min": 0.001227208376590668}}, "EndTime": 1557088389.668663, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668648}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.007262110921905269, "sum": 0.007262110921905269, "min": 0.007262110921905269}}, "EndTime": 1557088389.668717, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668703}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0012300430181969762, "sum": 0.0012300430181969762, "min": 0.0012300430181969762}}, "EndTime": 1557088389.668772, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668757}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0017746541261223691, "sum": 0.0017746541261223691, "min": 0.0017746541261223691}}, "EndTime": 1557088389.668828, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668812}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0016839187791298337, "sum": 0.0016839187791298337, "min": 0.0016839187791298337}}, "EndTime": 1557088389.668888, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668873}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0021368842226776046, "sum": 0.0021368842226776046, "min": 0.0021368842226776046}}, "EndTime": 1557088389.668947, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668932}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0016863974365116162, "sum": 0.0016863974365116162, "min": 0.0016863974365116162}}, "EndTime": 1557088389.669004, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.668989}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0018852544716330029, "sum": 0.0018852544716330029, "min": 0.0018852544716330029}}, "EndTime": 1557088389.66906, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.669045}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.001685850499514034, "sum": 0.001685850499514034, "min": 0.001685850499514034}}, "EndTime": 1557088389.669117, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.669102}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.00693849354585511, "sum": 0.00693849354585511, "min": 0.00693849354585511}}, "EndTime": 1557088389.669178, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.669162}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0017717259643065869, "sum": 0.0017717259643065869, "min": 0.0017717259643065869}}, "EndTime": 1557088389.669246, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.669229}
#
# #metrics {"Metrics": {"train_binary_classification_hinge_loss_objective": {"count": 1, "max": 0.0035563836549432136, "sum": 0.0035563836549432136, "min": 0.0035563836549432136}}, "EndTime": 1557088389.669303, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088389.669288}
#
# [05/05/2019 20:33:09 INFO 139688129685312] #quality_metric: host=algo-1, epoch=26, train binary_classification_hinge_loss_objective <loss>=0.000821753137413
# [05/05/2019 20:33:09 INFO 139688129685312] #early_stopping_criteria_metric: host=algo-1, epoch=26, criteria=binary_classification_hinge_loss_objective, value=0.000821753137413
# [05/05/2019 20:33:09 INFO 139688129685312] Early stop condition met. Stopping training.
# [05/05/2019 20:33:09 INFO 139688129685312] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 5412, "sum": 5412.0, "min": 5412}, "Total Records Seen": {"count": 1, "max": 5394828, "sum": 5394828.0, "min": 5394828}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 29, "sum": 29.0, "min": 29}}, "EndTime": 1557088389.67164, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 26}, "StartTime": 1557088383.07864}
#
# [05/05/2019 20:33:09 INFO 139688129685312] #throughput_metric: host=algo-1, train throughput=30238.0953858 records/second
# [05/05/2019 20:33:09 WARNING 139688129685312] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [05/05/2019 20:33:09 WARNING 139688129685312] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-05-05 20:33:09.672] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 28, "duration": 6593, "num_examples": 200}
# [2019-05-05 20:33:09.678] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 29, "duration": 6, "num_examples": 1}
# [2019-05-05 20:33:10.479] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 30, "duration": 797, "num_examples": 200}
# [05/05/2019 20:33:11 INFO 139688129685312] #train_score (algo-1) : ('binary_classification_hinge_loss_objective', 0.00082294680334379325)
# [05/05/2019 20:33:11 INFO 139688129685312] #train_score (algo-1) : ('binary_classification_accuracy', 0.89001524849019886)
# [05/05/2019 20:33:11 INFO 139688129685312] #train_score (algo-1) : ('binary_f_1.000', 0.026980252939871312)
# [05/05/2019 20:33:11 INFO 139688129685312] #train_score (algo-1) : ('precision', 0.013694927470943329)
# [05/05/2019 20:33:11 INFO 139688129685312] #train_score (algo-1) : ('recall', 0.9020771513353115)
# [05/05/2019 20:33:11 INFO 139688129685312] #quality_metric: host=algo-1, train binary_classification_hinge_loss_objective <loss>=0.000822946803344
# [05/05/2019 20:33:11 INFO 139688129685312] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.89001524849
# [05/05/2019 20:33:11 INFO 139688129685312] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.0269802529399
# [05/05/2019 20:33:11 INFO 139688129685312] #quality_metric: host=algo-1, train precision <score>=0.0136949274709
# [05/05/2019 20:33:11 INFO 139688129685312] #quality_metric: host=algo-1, train recall <score>=0.902077151335
# [05/05/2019 20:33:11 INFO 139688129685312] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [05/05/2019 20:33:11 INFO 139688129685312] Saved checkpoint to "/tmp/tmpwNydwT/mx-mod-0000.params"
# [05/05/2019 20:33:11 INFO 139688129685312] Test data is not provided.
# [2019-05-05 20:33:11.256] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 31, "duration": 777, "num_examples": 200}
# [2019-05-05 20:33:11.256] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "duration": 180382, "num_epochs": 32, "num_examples": 5813}
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 180679.29482460022, "sum": 180679.29482460022, "min": 180679.29482460022}, "finalize.time": {"count": 1, "max": 1570.9800720214844, "sum": 1570.9800720214844, "min": 1570.9800720214844}, "initialize.time": {"count": 1, "max": 353.58500480651855, "sum": 353.58500480651855, "min": 353.58500480651855}, "check_early_stopping.time": {"count": 27, "max": 1.0068416595458984, "sum": 19.953489303588867, "min": 0.1900196075439453}, "setuptime": {"count": 1, "max": 25.844812393188477, "sum": 25.844812393188477, "min": 25.844812393188477}, "update.time": {"count": 27, "max": 7372.604131698608, "sum": 178617.63167381287, "min": 6182.505130767822}, "epochs": {"count": 1, "max": 40, "sum": 40.0, "min": 40}}, "EndTime": 1557088391.256888, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1557088210.681548}
#
#
# 2019-05-05 20:33:18 Uploading - Uploading generated training model
# 2019-05-05 20:33:18 Completed - Training job completed
# INFO:sagemaker:Creating model with name: linear-learner-2019-05-05-20-33-39-443
# Billable seconds: 243
# INFO:sagemaker:Creating endpoint with name linear-learner-2019-05-05-20-27-25-506
# ---------------------------------------------------------------------------------------!

# %% [markdown]
# And finally, let's see what happens with balancing the class weights for the SVM model:

# %%
# Training a binary classifier with hinge loss, balanced class weights, and automated threshold tuning
svm_balanced_hyperparams = {
    'feature_dim': 30,
    'predictor_type': 'binary_classifier',
    'loss': 'hinge_loss',
    'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 
    'target_recall': 0.9,
    'positive_example_weight_mult': 'balanced',
    'epochs': 40
}
svm_balanced_output_path = 's3://{}/{}/svm_balanced/output'.format(bucket, prefix)
svm_balanced_predictor = predictor_from_hyperparams(s3_train_path, svm_balanced_hyperparams, svm_balanced_output_path)
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2019-05-05-20-40-59-885
# 2019-05-05 20:41:00 Starting - Starting the training job...
# 2019-05-05 20:41:01 Starting - Launching requested ML instances.........
# 2019-05-05 20:42:34 Starting - Preparing the instances for training...
# 2019-05-05 20:43:27 Downloading - Downloading input data...
# 2019-05-05 20:43:34 Training - Downloading the training image...
# 2019-05-05 20:44:20 Training - Training image download completed. Training in progress.
# Docker entrypoint called with argument(s): train
# [05/05/2019 20:44:22 INFO 140358071150400] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [05/05/2019 20:44:22 INFO 140358071150400] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'loss': u'hinge_loss', u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'40', u'positive_example_weight_mult': u'balanced', u'target_recall': u'0.9'}
# [05/05/2019 20:44:22 INFO 140358071150400] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'40', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'hinge_loss', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'balanced', u'l1': u'auto', u'margin': u'1.0'}
# [05/05/2019 20:44:22 WARNING 140358071150400] Loggers have already been setup.
# Process 1 is a worker.
# [05/05/2019 20:44:22 INFO 140358071150400] Using default worker.
# [2019-05-05 20:44:23.049] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/train", "num_examples": 1000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [30], "storage_type": "dense"}]}
# [2019-05-05 20:44:23.081] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 0, "duration": 33, "num_examples": 1}
# [05/05/2019 20:44:23 INFO 140358071150400] Create Store: local
# [2019-05-05 20:44:23.155] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 1, "duration": 73, "num_examples": 11}
# [05/05/2019 20:44:23 INFO 140358071150400] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fa758c94ad0>
# [05/05/2019 20:44:23 INFO 140358071150400] Scaling model computed with parameters:
#  {'stdev_weight':
# [  4.71942188e+04   2.01291966e+00   1.69568098e+00   1.57379591e+00
#    1.42111158e+00   1.74640667e+00   1.51144338e+00   1.63385201e+00
#    1.13653934e+00   1.08314764e+00   1.06824124e+00   1.03516150e+00
#    1.01673567e+00   9.92477775e-01   9.78726447e-01   9.13698077e-01
#    8.90511751e-01   8.58795881e-01   8.44277263e-01   8.11051309e-01
#    9.23640847e-01   7.29950190e-01   7.28531599e-01   6.56139612e-01
#    6.05293095e-01   5.20700455e-01   4.88954067e-01   5.05282402e-01
#    3.77208292e-01   3.40401947e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [  9.41158750e+04  -2.09659096e-02   6.00883830e-03  -6.06044414e-05
#    1.07088813e-03   2.56213127e-03   1.28126498e-02   5.70237590e-03
#    1.37717789e-02   5.02825656e-04  -1.49376029e-02   8.31487868e-03
#    2.41851507e-04  -7.11433776e-03  -6.22152584e-03   1.35600369e-03
#   -3.61267186e-04   4.83268918e-03  -3.69541849e-05   1.13776792e-03
#   -9.44486167e-03  -6.55637588e-03  -1.03078522e-02  -2.02503870e-03
#    3.76771495e-04  -1.49243438e-04   7.94459879e-03   1.23333558e-02
#    2.39625806e-03   8.90791397e+01]
# <NDArray 30 @cpu(0)>}
# [05/05/2019 20:44:23 INFO 140358071150400] nvidia-smi took: 0.0252439975739 secs to identify 0 gpus
# [05/05/2019 20:44:23 INFO 140358071150400] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1557089063.340556, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1557089063.340514}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.16092958097002613, "sum": 0.16092958097002613, "min": 0.16092958097002613}}, "EndTime": 1557089070.578529, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.578462}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.12853523888180604, "sum": 0.12853523888180604, "min": 0.12853523888180604}}, "EndTime": 1557089070.578626, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.578607}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.1377322000342997, "sum": 0.1377322000342997, "min": 0.1377322000342997}}, "EndTime": 1557089070.578688, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.578672}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.1618027046241952, "sum": 0.1618027046241952, "min": 0.1618027046241952}}, "EndTime": 1557089070.578756, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.57874}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.36354194922423244, "sum": 0.36354194922423244, "min": 0.36354194922423244}}, "EndTime": 1557089070.578814, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.578799}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.3779203838442438, "sum": 0.3779203838442438, "min": 0.3779203838442438}}, "EndTime": 1557089070.57887, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.578855}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.3667761081888448, "sum": 0.3667761081888448, "min": 0.3667761081888448}}, "EndTime": 1557089070.578924, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.57891}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.3596399926749905, "sum": 0.3596399926749905, "min": 0.3596399926749905}}, "EndTime": 1557089070.578982, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.578966}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.13195560392303082, "sum": 0.13195560392303082, "min": 0.13195560392303082}}, "EndTime": 1557089070.57904, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579024}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.16227767831356682, "sum": 0.16227767831356682, "min": 0.16227767831356682}}, "EndTime": 1557089070.579096, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.57908}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.1579987956159678, "sum": 0.1579987956159678, "min": 0.1579987956159678}}, "EndTime": 1557089070.579145, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579135}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.16357782098635956, "sum": 0.16357782098635956, "min": 0.16357782098635956}}, "EndTime": 1557089070.579197, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579182}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.3467955375268831, "sum": 0.3467955375268831, "min": 0.3467955375268831}}, "EndTime": 1557089070.579249, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579234}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.35938655600176383, "sum": 0.35938655600176383, "min": 0.35938655600176383}}, "EndTime": 1557089070.579305, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579289}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.3623571615632455, "sum": 0.3623571615632455, "min": 0.3623571615632455}}, "EndTime": 1557089070.57934, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579331}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.3587709351688174, "sum": 0.3587709351688174, "min": 0.3587709351688174}}, "EndTime": 1557089070.579369, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579361}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.16186334940057304, "sum": 0.16186334940057304, "min": 0.16186334940057304}}, "EndTime": 1557089070.579422, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579412}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.13040782285575292, "sum": 0.13040782285575292, "min": 0.13040782285575292}}, "EndTime": 1557089070.579458, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579445}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.13746685185863744, "sum": 0.13746685185863744, "min": 0.13746685185863744}}, "EndTime": 1557089070.579513, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579499}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.14286334946646762, "sum": 0.14286334946646762, "min": 0.14286334946646762}}, "EndTime": 1557089070.579563, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579548}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2561118331985857, "sum": 0.2561118331985857, "min": 0.2561118331985857}}, "EndTime": 1557089070.579627, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579612}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.25924996262519207, "sum": 0.25924996262519207, "min": 0.25924996262519207}}, "EndTime": 1557089070.579688, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579672}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2553246871790095, "sum": 0.2553246871790095, "min": 0.2553246871790095}}, "EndTime": 1557089070.579747, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579731}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.27091826027302285, "sum": 0.27091826027302285, "min": 0.27091826027302285}}, "EndTime": 1557089070.579807, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579792}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2819639437553197, "sum": 0.2819639437553197, "min": 0.2819639437553197}}, "EndTime": 1557089070.579868, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579851}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.285711909155001, "sum": 0.285711909155001, "min": 0.285711909155001}}, "EndTime": 1557089070.579921, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579906}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.3249538529222485, "sum": 0.3249538529222485, "min": 0.3249538529222485}}, "EndTime": 1557089070.57998, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.579965}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2938725867257196, "sum": 0.2938725867257196, "min": 0.2938725867257196}}, "EndTime": 1557089070.58003, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.580015}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.5717273241661901, "sum": 0.5717273241661901, "min": 0.5717273241661901}}, "EndTime": 1557089070.58008, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.580066}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.5631068779299008, "sum": 0.5631068779299008, "min": 0.5631068779299008}}, "EndTime": 1557089070.580142, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.580127}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.5963384267791881, "sum": 0.5963384267791881, "min": 0.5963384267791881}}, "EndTime": 1557089070.580197, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.580182}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.6159434721111203, "sum": 0.6159434721111203, "min": 0.6159434721111203}}, "EndTime": 1557089070.580256, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089070.58024}
#
# [05/05/2019 20:44:30 INFO 140358071150400] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_hinge_loss_objective <loss>=0.16092958097
# [05/05/2019 20:44:30 INFO 140358071150400] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_hinge_loss_objective, value=0.128535238882
# [05/05/2019 20:44:30 INFO 140358071150400] Epoch 0: Loss improved. Updating best model
# [05/05/2019 20:44:30 INFO 140358071150400] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1557089070.583865, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557089063.340772}
#
# [05/05/2019 20:44:30 INFO 140358071150400] #throughput_metric: host=algo-1, train throughput=27524.2114352 records/second
# [2019-05-05 20:44:30.584] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 2, "duration": 7243, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11193193593815942, "sum": 0.11193193593815942, "min": 0.11193193593815942}}, "EndTime": 1557089078.130503, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.130434}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11371130642579429, "sum": 0.11371130642579429, "min": 0.11371130642579429}}, "EndTime": 1557089078.130599, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.130579}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11086685336414893, "sum": 0.11086685336414893, "min": 0.11086685336414893}}, "EndTime": 1557089078.130659, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.130644}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11500034299927141, "sum": 0.11500034299927141, "min": 0.11500034299927141}}, "EndTime": 1557089078.130715, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.130701}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.30677635423861555, "sum": 0.30677635423861555, "min": 0.30677635423861555}}, "EndTime": 1557089078.130767, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.130754}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.35881283810869535, "sum": 0.35881283810869535, "min": 0.35881283810869535}}, "EndTime": 1557089078.130818, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.130804}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.301167067240231, "sum": 0.301167067240231, "min": 0.301167067240231}}, "EndTime": 1557089078.130876, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.13086}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.41852755621809457, "sum": 0.41852755621809457, "min": 0.41852755621809457}}, "EndTime": 1557089078.130935, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.130919}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11195855928066388, "sum": 0.11195855928066388, "min": 0.11195855928066388}}, "EndTime": 1557089078.130994, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.130978}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.1135178388926252, "sum": 0.1135178388926252, "min": 0.1135178388926252}}, "EndTime": 1557089078.131059, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131043}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11088872945967632, "sum": 0.11088872945967632, "min": 0.11088872945967632}}, "EndTime": 1557089078.131124, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131108}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11335855488561505, "sum": 0.11335855488561505, "min": 0.11335855488561505}}, "EndTime": 1557089078.131185, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131168}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.26414843954872247, "sum": 0.26414843954872247, "min": 0.26414843954872247}}, "EndTime": 1557089078.131242, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131227}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.297388841868645, "sum": 0.297388841868645, "min": 0.297388841868645}}, "EndTime": 1557089078.131298, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131283}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2902801856120028, "sum": 0.2902801856120028, "min": 0.2902801856120028}}, "EndTime": 1557089078.131358, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131341}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.29660724435739183, "sum": 0.29660724435739183, "min": 0.29660724435739183}}, "EndTime": 1557089078.131444, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131427}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.12113617698391478, "sum": 0.12113617698391478, "min": 0.12113617698391478}}, "EndTime": 1557089078.1315, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131485}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.12315415383583338, "sum": 0.12315415383583338, "min": 0.12315415383583338}}, "EndTime": 1557089078.131554, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.13154}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.12139681928481288, "sum": 0.12139681928481288, "min": 0.12139681928481288}}, "EndTime": 1557089078.131612, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131596}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.12237129254077547, "sum": 0.12237129254077547, "min": 0.12237129254077547}}, "EndTime": 1557089078.131682, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131665}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.22644459524585972, "sum": 0.22644459524585972, "min": 0.22644459524585972}}, "EndTime": 1557089078.13175, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131734}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2606050445218781, "sum": 0.2606050445218781, "min": 0.2606050445218781}}, "EndTime": 1557089078.131822, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131804}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.22651118099959053, "sum": 0.22651118099959053, "min": 0.22651118099959053}}, "EndTime": 1557089078.131891, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131874}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.27454182650695497, "sum": 0.27454182650695497, "min": 0.27454182650695497}}, "EndTime": 1557089078.131959, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.131942}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.276665155716203, "sum": 0.276665155716203, "min": 0.276665155716203}}, "EndTime": 1557089078.132019, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.132003}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2810981207370908, "sum": 0.2810981207370908, "min": 0.2810981207370908}}, "EndTime": 1557089078.132078, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.132062}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2752495663386194, "sum": 0.2752495663386194, "min": 0.2752495663386194}}, "EndTime": 1557089078.132137, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.132121}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.28210043446596095, "sum": 0.28210043446596095, "min": 0.28210043446596095}}, "EndTime": 1557089078.132203, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.132186}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.5100237460920409, "sum": 0.5100237460920409, "min": 0.5100237460920409}}, "EndTime": 1557089078.132272, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.132255}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.6039304675895665, "sum": 0.6039304675895665, "min": 0.6039304675895665}}, "EndTime": 1557089078.132335, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.132318}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.46266486913048144, "sum": 0.46266486913048144, "min": 0.46266486913048144}}, "EndTime": 1557089078.132401, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.132386}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.5873600275737406, "sum": 0.5873600275737406, "min": 0.5873600275737406}}, "EndTime": 1557089078.132464, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089078.132448}
#
# [05/05/2019 20:44:38 INFO 140358071150400] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_hinge_loss_objective <loss>=0.111931935938
# [05/05/2019 20:44:38 INFO 140358071150400] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_hinge_loss_objective, value=0.110866853364
# [05/05/2019 20:44:38 INFO 140358071150400] Epoch 1: Loss improved. Updating best model
# [05/05/2019 20:44:38 INFO 140358071150400] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1557089078.135555, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557089070.584194}
#
# [05/05/2019 20:44:38 INFO 140358071150400] #throughput_metric: host=algo-1, train throughput=26400.610719 records/second
# [2019-05-05 20:44:38.135] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 3, "duration": 7551, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.10847666144251224, "sum": 0.10847666144251224, "min": 0.10847666144251224}}, "EndTime": 1557089085.548257, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.548189}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11245101552752394, "sum": 0.11245101552752394, "min": 0.11245101552752394}}, "EndTime": 1557089085.548349, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.548329}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.10845503079112451, "sum": 0.10845503079112451, "min": 0.10845503079112451}}, "EndTime": 1557089085.548411, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.548395}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11255705495335948, "sum": 0.11255705495335948, "min": 0.11255705495335948}}, "EndTime": 1557089085.548471, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.548455}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2524830079102636, "sum": 0.2524830079102636, "min": 0.2524830079102636}}, "EndTime": 1557089085.548528, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.548513}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.44854627390722535, "sum": 0.44854627390722535, "min": 0.44854627390722535}}, "EndTime": 1557089085.548589, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.548572}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2528767475434883, "sum": 0.2528767475434883, "min": 0.2528767475434883}}, "EndTime": 1557089085.548646, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.54863}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.32741283123457254, "sum": 0.32741283123457254, "min": 0.32741283123457254}}, "EndTime": 1557089085.548701, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.548686}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.10864949190197279, "sum": 0.10864949190197279, "min": 0.10864949190197279}}, "EndTime": 1557089085.548759, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.548742}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11169363405716479, "sum": 0.11169363405716479, "min": 0.11169363405716479}}, "EndTime": 1557089085.548818, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.548801}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.1090684847472301, "sum": 0.1090684847472301, "min": 0.1090684847472301}}, "EndTime": 1557089085.548875, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.54886}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.1110889219446997, "sum": 0.1110889219446997, "min": 0.1110889219446997}}, "EndTime": 1557089085.548932, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.548917}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2828073956618956, "sum": 0.2828073956618956, "min": 0.2828073956618956}}, "EndTime": 1557089085.54899, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.548974}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.34504651282899945, "sum": 0.34504651282899945, "min": 0.34504651282899945}}, "EndTime": 1557089085.549048, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549033}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.262639986757058, "sum": 0.262639986757058, "min": 0.262639986757058}}, "EndTime": 1557089085.549108, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549092}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.34443542625197215, "sum": 0.34443542625197215, "min": 0.34443542625197215}}, "EndTime": 1557089085.549172, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549156}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.12000872816632141, "sum": 0.12000872816632141, "min": 0.12000872816632141}}, "EndTime": 1557089085.54923, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549214}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.12170542705238764, "sum": 0.12170542705238764, "min": 0.12170542705238764}}, "EndTime": 1557089085.549286, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549271}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.12020027827737319, "sum": 0.12020027827737319, "min": 0.12020027827737319}}, "EndTime": 1557089085.549344, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549329}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.12122589413963969, "sum": 0.12122589413963969, "min": 0.12122589413963969}}, "EndTime": 1557089085.549406, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.54939}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.19337503132209108, "sum": 0.19337503132209108, "min": 0.19337503132209108}}, "EndTime": 1557089085.549463, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549447}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.21944819212888353, "sum": 0.21944819212888353, "min": 0.21944819212888353}}, "EndTime": 1557089085.549522, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549506}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.19339920462196197, "sum": 0.19339920462196197, "min": 0.19339920462196197}}, "EndTime": 1557089085.549581, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549566}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2240749670680444, "sum": 0.2240749670680444, "min": 0.2240749670680444}}, "EndTime": 1557089085.549633, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549618}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2768133222984908, "sum": 0.2768133222984908, "min": 0.2768133222984908}}, "EndTime": 1557089085.549695, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.54968}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2814708411705554, "sum": 0.2814708411705554, "min": 0.2814708411705554}}, "EndTime": 1557089085.549751, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549736}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.27591284296620433, "sum": 0.27591284296620433, "min": 0.27591284296620433}}, "EndTime": 1557089085.549814, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549798}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2817224202167112, "sum": 0.2817224202167112, "min": 0.2817224202167112}}, "EndTime": 1557089085.549872, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549855}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.43183746972238296, "sum": 0.43183746972238296, "min": 0.43183746972238296}}, "EndTime": 1557089085.54993, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549914}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.5064738444652989, "sum": 0.5064738444652989, "min": 0.5064738444652989}}, "EndTime": 1557089085.549994, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.549978}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.468913167790477, "sum": 0.468913167790477, "min": 0.468913167790477}}, "EndTime": 1557089085.55005, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.550035}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.5837634796261338, "sum": 0.5837634796261338, "min": 0.5837634796261338}}, "EndTime": 1557089085.550109, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089085.550094}
#
# [05/05/2019 20:44:45 INFO 140358071150400] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_hinge_loss_objective <loss>=0.108476661443
# [05/05/2019 20:44:45 INFO 140358071150400] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_hinge_loss_objective, value=0.108455030791
# [05/05/2019 20:44:45 INFO 140358071150400] Epoch 2: Loss improved. Updating best model
# [05/05/2019 20:44:45 INFO 140358071150400] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1557089085.553125, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557089078.135876}
#
# [05/05/2019 20:44:45 INFO 140358071150400] #throughput_metric: host=algo-1, train throughput=26877.8856163 records/second
# [2019-05-05 20:44:45.553] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 4, "duration": 7417, "num_examples": 200}
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.10718228025292631, "sum": 0.10718228025292631, "min": 0.10718228025292631}}, "EndTime": 1557089093.09884, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557089093.098771}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11234897087806434, "sum": 0.11234897087806434, "min": 0.11234897087806434}}, "EndTime": 1557089093.098931, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557089093.098912}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.10709718171795408, "sum": 0.10709718171795408, "min": 0.10709718171795408}}, "EndTime": 1557089093.098992, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557089093.098977}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11227294953983633, "sum": 0.11227294953983633, "min": 0.11227294953983633}}, "EndTime": 1557089093.099052, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557089093.099037}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2741401581261026, "sum": 0.2741401581261026, "min": 0.2741401581261026}}, "EndTime": 1557089093.099104, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557089093.09909}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.1064002183789584, "sum": 0.1064002183789584, "min": 0.1064002183789584}}, "EndTime": 1557089240.942279, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.942268}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11182784136096437, "sum": 0.11182784136096437, "min": 0.11182784136096437}}, "EndTime": 1557089240.94232, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.942306}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.29988127716582025, "sum": 0.29988127716582025, "min": 0.29988127716582025}}, "EndTime": 1557089240.942376, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.94236}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11174810364497965, "sum": 0.11174810364497965, "min": 0.11174810364497965}}, "EndTime": 1557089240.942432, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.942417}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.3271977094429821, "sum": 0.3271977094429821, "min": 0.3271977094429821}}, "EndTime": 1557089240.942486, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.942471}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.09811041539637887, "sum": 0.09811041539637887, "min": 0.09811041539637887}}, "EndTime": 1557089240.942543, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.942527}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.1072843394782675, "sum": 0.1072843394782675, "min": 0.1072843394782675}}, "EndTime": 1557089240.942602, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.942586}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.09871807395513334, "sum": 0.09871807395513334, "min": 0.09871807395513334}}, "EndTime": 1557089240.942659, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.942644}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.1069200101449861, "sum": 0.1069200101449861, "min": 0.1069200101449861}}, "EndTime": 1557089240.942719, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.942701}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.10051487352860033, "sum": 0.10051487352860033, "min": 0.10051487352860033}}, "EndTime": 1557089240.942776, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.94276}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.23215156907172657, "sum": 0.23215156907172657, "min": 0.23215156907172657}}, "EndTime": 1557089240.942844, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.942827}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.10018923311377291, "sum": 0.10018923311377291, "min": 0.10018923311377291}}, "EndTime": 1557089240.942913, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.942896}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.23227391924450744, "sum": 0.23227391924450744, "min": 0.23227391924450744}}, "EndTime": 1557089240.942983, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.942966}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11335802807640191, "sum": 0.11335802807640191, "min": 0.11335802807640191}}, "EndTime": 1557089240.943046, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.94303}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.12035759559708024, "sum": 0.12035759559708024, "min": 0.12035759559708024}}, "EndTime": 1557089240.943115, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943098}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11359073766871314, "sum": 0.11359073766871314, "min": 0.11359073766871314}}, "EndTime": 1557089240.943183, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943166}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.12035311477747394, "sum": 0.12035311477747394, "min": 0.12035311477747394}}, "EndTime": 1557089240.943243, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943227}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11651515258137306, "sum": 0.11651515258137306, "min": 0.11651515258137306}}, "EndTime": 1557089240.943298, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943284}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.20549271102526678, "sum": 0.20549271102526678, "min": 0.20549271102526678}}, "EndTime": 1557089240.943357, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943341}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.11651425853805926, "sum": 0.11651425853805926, "min": 0.11651425853805926}}, "EndTime": 1557089240.94344, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943426}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.1952672553062439, "sum": 0.1952672553062439, "min": 0.1952672553062439}}, "EndTime": 1557089240.943474, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943466}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2660193322459657, "sum": 0.2660193322459657, "min": 0.2660193322459657}}, "EndTime": 1557089240.943511, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943499}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2743718405043959, "sum": 0.2743718405043959, "min": 0.2743718405043959}}, "EndTime": 1557089240.94357, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943554}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2664481347745387, "sum": 0.2664481347745387, "min": 0.2664481347745387}}, "EndTime": 1557089240.943639, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943622}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.2743676770248605, "sum": 0.2743676770248605, "min": 0.2743676770248605}}, "EndTime": 1557089240.943702, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943685}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.26656496010473624, "sum": 0.26656496010473624, "min": 0.26656496010473624}}, "EndTime": 1557089240.94376, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943745}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.4345591774466799, "sum": 0.4345591774466799, "min": 0.4345591774466799}}, "EndTime": 1557089240.943822, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943806}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.266566581981266, "sum": 0.266566581981266, "min": 0.266566581981266}}, "EndTime": 1557089240.94388, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943864}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_hinge_loss_objective": {"count": 1, "max": 0.4844558022416866, "sum": 0.4844558022416866, "min": 0.4844558022416866}}, "EndTime": 1557089240.943945, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089240.943931}
#
# [05/05/2019 20:47:20 INFO 140358071150400] #quality_metric: host=algo-1, epoch=23, train binary_classification_weighted_hinge_loss_objective <loss>=0.0981641182684
# [05/05/2019 20:47:20 INFO 140358071150400] #early_stopping_criteria_metric: host=algo-1, epoch=23, criteria=binary_classification_weighted_hinge_loss_objective, value=0.0979570970152
# [05/05/2019 20:47:20 INFO 140358071150400] Early stop condition met. Stopping training.
# [05/05/2019 20:47:20 INFO 140358071150400] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 4812, "sum": 4812.0, "min": 4812}, "Total Records Seen": {"count": 1, "max": 4796736, "sum": 4796736.0, "min": 4796736}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 26, "sum": 26.0, "min": 26}}, "EndTime": 1557089240.946749, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 23}, "StartTime": 1557089233.710864}
#
# [05/05/2019 20:47:20 INFO 140358071150400] #throughput_metric: host=algo-1, train throughput=27551.6249596 records/second
# [05/05/2019 20:47:20 WARNING 140358071150400] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [05/05/2019 20:47:20 WARNING 140358071150400] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-05-05 20:47:20.947] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 25, "duration": 7236, "num_examples": 200}
# [2019-05-05 20:47:20.957] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 26, "duration": 10, "num_examples": 1}
# [2019-05-05 20:47:21.692] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 27, "duration": 730, "num_examples": 200}
# [05/05/2019 20:47:22 INFO 140358071150400] #train_score (algo-1) : ('binary_classification_weighted_hinge_loss_objective', 0.0975288582954109)
# [05/05/2019 20:47:22 INFO 140358071150400] #train_score (algo-1) : ('binary_classification_accuracy', 0.98610080054573546)
# [05/05/2019 20:47:22 INFO 140358071150400] #train_score (algo-1) : ('binary_f_1.000', 0.1799348919798757)
# [05/05/2019 20:47:22 INFO 140358071150400] #train_score (algo-1) : ('precision', 0.09993425378040763)
# [05/05/2019 20:47:22 INFO 140358071150400] #train_score (algo-1) : ('recall', 0.9020771513353115)
# [05/05/2019 20:47:22 INFO 140358071150400] #quality_metric: host=algo-1, train binary_classification_weighted_hinge_loss_objective <loss>=0.0975288582954
# [05/05/2019 20:47:22 INFO 140358071150400] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.986100800546
# [05/05/2019 20:47:22 INFO 140358071150400] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.17993489198
# [05/05/2019 20:47:22 INFO 140358071150400] #quality_metric: host=algo-1, train precision <score>=0.0999342537804
# [05/05/2019 20:47:22 INFO 140358071150400] #quality_metric: host=algo-1, train recall <score>=0.902077151335
# [05/05/2019 20:47:22 INFO 140358071150400] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 0.0001}
# [05/05/2019 20:47:22 INFO 140358071150400] Saved checkpoint to "/tmp/tmph_QTRa/mx-mod-0000.params"
# [05/05/2019 20:47:22 INFO 140358071150400] Test data is not provided.
# [2019-05-05 20:47:22.449] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 28, "duration": 757, "num_examples": 200}
# [2019-05-05 20:47:22.449] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "duration": 179191, "num_epochs": 29, "num_examples": 5213}
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 179494.39096450806, "sum": 179494.39096450806, "min": 179494.39096450806}, "finalize.time": {"count": 1, "max": 1490.4558658599854, "sum": 1490.4558658599854, "min": 1490.4558658599854}, "initialize.time": {"count": 1, "max": 288.1200313568115, "sum": 288.1200313568115, "min": 288.1200313568115}, "check_early_stopping.time": {"count": 24, "max": 0.9980201721191406, "sum": 17.6239013671875, "min": 0.1888275146484375}, "setuptime": {"count": 1, "max": 17.821073532104492, "sum": 17.821073532104492, "min": 17.821073532104492}, "update.time": {"count": 24, "max": 7790.105819702148, "sum": 177594.41566467285, "min": 6889.060974121094}, "epochs": {"count": 1, "max": 40, "sum": 40.0, "min": 40}}, "EndTime": 1557089242.450063, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1557089063.046994}
# INFO:sagemaker:Creating model with name: linear-learner-2019-05-05-20-47-43-811
# Billable seconds: 244
# INFO:sagemaker:Creating endpoint with name linear-learner-2019-05-05-20-40-59-885
# ----------------------------------------------------------------------------------------!

# %% [markdown]
# Now we'll make use of the prediction endpoint we've set up for each model by sending them features from the test set and evaluating their predictions with standard binary classification metrics.

# %%
# Evaluate the trained models
predictors = {'Logistic': defaults_predictor, 'Logistic with auto threshold': autothresh_predictor, 
              'Logistic with class weights': class_weights_predictor, 'Hinge with auto threshold': svm_predictor, 
              'Hinge with class weights': svm_balanced_predictor}
metrics = {key: evaluate(predictor, test_features, test_labels, key, False) for key, predictor in predictors.items()}
pd.set_option('display.float_format', lambda x: '%.3f' % x)
display(pd.DataFrame(list(metrics.values())).loc[:, ['Model', 'Recall', 'Precision', 'Accuracy', 'F1']])
# Out:
#                           Model  Recall  Precision  Accuracy    F1
# 0                      Logistic   0.677      0.861     0.999 0.758
# 1  Logistic with auto threshold   0.903      0.053     0.971 0.101
# 2   Logistic with class weights   0.910      0.128     0.989 0.225
# 3     Hinge with auto threshold   0.916      0.015     0.889 0.029
# 4      Hinge with class weights   0.903      0.108     0.986 0.193

# %% [markdown]
# The results are in!  With threshold tuning, we can accurately predict 85-90% of the fraudulent transactions in the test set (due to randomness in training, recall will vary between 0.85-0.9 across multiple runs).  But in addition to those true positives, we'll have a high number of false positives: 90-95% of the transactions we predict to be fraudulent are in fact not fraudulent (precision varies between 0.05-0.1).  This model would work well as a first line of defense, flagging potentially fraudulent transactions for further review.  If we instead want a model that gives very few false alarms, at the cost of catching far fewer of the fraudulent transactions, then we should optimize for higher precision:

# %% [markdown]
#     binary_classifier_model_selection_criteria='recall_at_target_precision',
#     target_precision=0.9,

# %% [markdown]
# And what about the results of using our new feature, class weights for binary classification?  Training with class weights has made a huge improvement to this model's performance!  The precision is roughly doubled, while recall is still held constant at 85-90%.
#
# Balancing class weights improved the performance of our SVM predictor, but it still does not match the corresponding logistic regression model for this dataset.  Comparing all of the models we've fit so far, logistic regression with class weights and tuned thresholds did the best.

# %% [markdown]
# #### Note on target vs. observed recall
#
# It's worth taking some time to look more closely at these results.  If we asked linear learner for a model calibrated to a target recall of 0.9, then why didn't we get exactly 90% recall on the test set?  The reason is the difference between training, validation, and testing.  Linear learner calibrates thresholds for binary classification on the validation data set when one is provided, or else on the training set.  Since we did not provide a validation data set, the threshold were calculated on the training data.  Since the training, validation, and test data sets don't match exactly, the target recall we request is only an approximation.  In this case, the threshold that produced 90% recall on the training data happened to produce only 85-90% recall on the test data (due to some randomness in training, the results will vary from one run to the next).  The variation of recall in the test set versus the training set is dependent on the number of positive points. In this example, although we have over 280,000 examples in the entire dataset, we only have 337 positive examples, hence the large difference.  The accuracy of this approximation can be improved by providing a large validation data set to get a more accurate threshold, and then evaluating on a large test set to get a more accurate benchmark of the model and its threshold.  For even more fine-grained control, we can set the number of calibration samples to a higher number.  It's default value is already quite high at 10 million samples:
#
#     num_calibration_samples=10000000,

# %% [markdown]
# #### Clean Up
#
# Finally we'll clean up by deleting the prediction endpoints we set up:

# %%
for predictor in [defaults_predictor, autothresh_predictor, class_weights_predictor, 
                  svm_predictor, svm_balanced_predictor]:
    delete_endpoint(predictor)

# %% [markdown]
# We've just shown how to use the linear learner new early stopping feature, new loss functions, and new class weights feature to improve credit card fraud prediction.  Class weights can help you optimize recall or precision for all types of fraud detection, as well as other classification problems with rare events, like ad click prediction or mechanical failure prediction.  Try using class weights in your binary classification problem, or try one of the new loss functions for your regression problems: use quantile prediction to put confidence intervals around your predictions by learning 5% and 95% quantiles.  For more information about new loss functions and class weights, see the linear learner [documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/linear-learner.html).

# %% [markdown]
# ##### References
# Andrea Dal Pozzolo, Olivier Caelen, Reid A. Johnson and Gianluca Bontempi. Calibrating Probability with Undersampling for Unbalanced Classification. In Symposium on Computational Intelligence and Data Mining (CIDM), IEEE, 2015.  See link to full license text on [Kaggle](https://www.kaggle.com/mlg-ulb/creditcardfraud).
